# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings
import json

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers
import sys

sys.path.insert(0, "../concordia")
# import concordia_dev
# print(concordia_dev.__file__)
from concordia import components as generic_components
from concordia.agents import deprecated_agent as basic_agent
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.clocks import game_clock
from concordia.components.agent import to_be_deprecated as components
from concordia.components import game_master as gm_components

# from concordia_dev.environment import game_master
# from concordia_dev.language_model import amazon_bedrock_model, gpt_model
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model, ollama_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env
import re

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = True

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()
# Out:
# 2024-12-14T22:53:43.764604+0000 INFO Successfully loaded .env file.
# 2024-12-14T22:53:43.765511+0000 INFO API_BASE_URL: https://mastodon.genexergy.org
# 2024-12-14T22:53:43.766343+0000 INFO EMAIL_PREFIX: gefi
# 2024-12-14T22:53:43.766820+0000 INFO MASTODON_CLIENT_ID: D*****************************************E
# 2024-12-14T22:53:43.767274+0000 INFO MASTODON_CLIENT_SECRET: A*****************************************s
# 2024-12-14T22:53:43.768913+0000 INFO USER0159_PASSWORD: 7******************************4
# 2024-12-14T22:53:43.770855+0000 INFO USER0121_PASSWORD: 0******************************9
# 2024-12-14T22:53:43.771421+0000 INFO USER0027_PASSWORD: 5******************************e
# 2024-12-14T22:53:43.772003+0000 INFO USER0013_PASSWORD: 8******************************8
# 2024-12-14T22:53:43.772898+0000 INFO USER0046_PASSWORD: e******************************d
# 2024-12-14T22:53:43.774111+0000 INFO USER0152_PASSWORD: 6******************************9
# 2024-12-14T22:53:43.774612+0000 INFO USER0151_PASSWORD: a******************************2
# 2024-12-14T22:53:43.775521+0000 INFO USER0021_PASSWORD: 1******************************a
# 2024-12-14T22:53:43.776922+0000 INFO USER0176_PASSWORD: 9******************************4
# 2024-12-14T22:53:43.777513+0000 INFO USER0189_PASSWORD: d******************************a
# 2024-12-14T22:53:43.778112+0000 INFO USER0042_PASSWORD: c******************************4
# 2024-12-14T22:53:43.778653+0000 INFO USER0136_PASSWORD: d******************************e
# 2024-12-14T22:53:43.779317+0000 INFO USER0171_PASSWORD: 4******************************1
# 2024-12-14T22:53:43.779797+0000 INFO USER0149_PASSWORD: d******************************9
# 2024-12-14T22:53:43.780466+0000 INFO USER0086_PASSWORD: 1******************************f
# 2024-12-14T22:53:43.781968+0000 INFO USER0030_PASSWORD: 4******************************6
# 2024-12-14T22:53:43.783516+0000 INFO USER0123_PASSWORD: 0******************************3
# 2024-12-14T22:53:43.784191+0000 INFO USER0003_PASSWORD: 0******************************f
# 2024-12-14T22:53:43.785078+0000 INFO USER0031_PASSWORD: 4******************************1
# 2024-12-14T22:53:43.787568+0000 INFO USER0111_PASSWORD: e******************************d
# 2024-12-14T22:53:43.788965+0000 INFO USER0169_PASSWORD: 0******************************c
# 2024-12-14T22:53:43.790086+0000 INFO USER0113_PASSWORD: 8******************************2
# 2024-12-14T22:53:43.791585+0000 INFO USER0078_PASSWORD: 1******************************d
# 2024-12-14T22:53:43.792998+0000 INFO USER0174_PASSWORD: 8******************************a
# 2024-12-14T22:53:43.794471+0000 INFO USER0107_PASSWORD: 9******************************7
# 2024-12-14T22:53:43.795199+0000 INFO USER0112_PASSWORD: a******************************e
# 2024-12-14T22:53:43.795586+0000 INFO USER0079_PASSWORD: 7******************************1
# 2024-12-14T22:53:43.796054+0000 INFO USER0011_PASSWORD: d******************************a
# 2024-12-14T22:53:43.796795+0000 INFO USER0173_PASSWORD: 9******************************c
# 2024-12-14T22:53:43.797496+0000 INFO USER0052_PASSWORD: 1******************************3
# 2024-12-14T22:53:43.798131+0000 INFO USER0074_PASSWORD: 0******************************a
# 2024-12-14T22:53:43.799160+0000 INFO USER0161_PASSWORD: c******************************9
# 2024-12-14T22:53:43.800291+0000 INFO USER0093_PASSWORD: 1******************************7
# 2024-12-14T22:53:43.801310+0000 INFO USER0090_PASSWORD: c******************************f
# 2024-12-14T22:53:43.802766+0000 INFO USER0034_PASSWORD: 9******************************4
# 2024-12-14T22:53:43.803439+0000 INFO USER0135_PASSWORD: 2******************************b
# 2024-12-14T22:53:43.804143+0000 INFO USER0125_PASSWORD: b******************************7
# 2024-12-14T22:53:43.805205+0000 INFO USER0167_PASSWORD: 0******************************7
# 2024-12-14T22:53:43.806319+0000 INFO USER0064_PASSWORD: 8******************************6
# 2024-12-14T22:53:43.807044+0000 INFO USER0053_PASSWORD: 6******************************d
# 2024-12-14T22:53:43.807474+0000 INFO USER0018_PASSWORD: e******************************d
# 2024-12-14T22:53:43.808016+0000 INFO USER0006_PASSWORD: 5******************************7
# 2024-12-14T22:53:43.808438+0000 INFO USER0084_PASSWORD: 0******************************e
# 2024-12-14T22:53:43.809355+0000 INFO USER0186_PASSWORD: 7******************************5
# 2024-12-14T22:53:43.810776+0000 INFO USER0177_PASSWORD: 6******************************5
# 2024-12-14T22:53:43.811478+0000 INFO USER0193_PASSWORD: 6******************************c
# 2024-12-14T22:53:43.811952+0000 INFO USER0162_PASSWORD: 5******************************2
# 2024-12-14T22:53:43.812367+0000 INFO USER0178_PASSWORD: 1******************************d
# 2024-12-14T22:53:43.812835+0000 INFO USER0182_PASSWORD: 7******************************5
# 2024-12-14T22:53:43.813538+0000 INFO USER0033_PASSWORD: c******************************3
# 2024-12-14T22:53:43.813948+0000 INFO USER0026_PASSWORD: b******************************4
# 2024-12-14T22:53:43.814688+0000 INFO USER0154_PASSWORD: 8******************************c
# 2024-12-14T22:53:43.815319+0000 INFO USER0025_PASSWORD: 8******************************7
# 2024-12-14T22:53:43.815811+0000 INFO USER0188_PASSWORD: 9******************************9
# 2024-12-14T22:53:43.816360+0000 INFO USER0103_PASSWORD: 8******************************9
# 2024-12-14T22:53:43.817079+0000 INFO USER0116_PASSWORD: e******************************0
# 2024-12-14T22:53:43.817479+0000 INFO USER0037_PASSWORD: 6******************************5
# 2024-12-14T22:53:43.817915+0000 INFO USER0115_PASSWORD: 8******************************3
# 2024-12-14T22:53:43.818480+0000 INFO USER0054_PASSWORD: 5******************************3
# 2024-12-14T22:53:43.819827+0000 INFO USER0132_PASSWORD: 4******************************3
# 2024-12-14T22:53:43.820629+0000 INFO USER0104_PASSWORD: 8******************************b
# 2024-12-14T22:53:43.821778+0000 INFO USER0150_PASSWORD: d******************************6
# 2024-12-14T22:53:43.822769+0000 INFO USER0142_PASSWORD: b******************************a
# 2024-12-14T22:53:43.823757+0000 INFO USER0081_PASSWORD: c******************************8
# 2024-12-14T22:53:43.824556+0000 INFO USER0091_PASSWORD: a******************************f
# 2024-12-14T22:53:43.825247+0000 INFO USER0083_PASSWORD: 0******************************a
# 2024-12-14T22:53:43.825723+0000 INFO USER0183_PASSWORD: a******************************9
# 2024-12-14T22:53:43.827137+0000 INFO USER0134_PASSWORD: b******************************9
# 2024-12-14T22:53:43.827686+0000 INFO USER0191_PASSWORD: c******************************c
# 2024-12-14T22:53:43.828145+0000 INFO USER0095_PASSWORD: e******************************1
# 2024-12-14T22:53:43.829097+0000 INFO USER0140_PASSWORD: c******************************a
# 2024-12-14T22:53:43.829615+0000 INFO USER0047_PASSWORD: 5******************************8
# 2024-12-14T22:53:43.830045+0000 INFO USER0181_PASSWORD: 6******************************0
# 2024-12-14T22:53:43.830454+0000 INFO USER0015_PASSWORD: c******************************5
# 2024-12-14T22:53:43.831501+0000 INFO USER0101_PASSWORD: 2******************************c
# 2024-12-14T22:53:43.832011+0000 INFO USER0008_PASSWORD: 8******************************a
# 2024-12-14T22:53:43.832792+0000 INFO USER0106_PASSWORD: 3******************************7
# 2024-12-14T22:53:43.833273+0000 INFO USER0082_PASSWORD: c******************************5
# 2024-12-14T22:53:43.833760+0000 INFO USER0098_PASSWORD: a******************************5
# 2024-12-14T22:53:43.834663+0000 INFO USER0049_PASSWORD: 1******************************8
# 2024-12-14T22:53:43.835166+0000 INFO USER0163_PASSWORD: 4******************************8
# 2024-12-14T22:53:43.835661+0000 INFO USER0092_PASSWORD: 6******************************2
# 2024-12-14T22:53:43.836580+0000 INFO USER0143_PASSWORD: 3******************************d
# 2024-12-14T22:53:43.837107+0000 INFO USER0085_PASSWORD: 8******************************e
# 2024-12-14T22:53:43.837554+0000 INFO USER0179_PASSWORD: c******************************9
# 2024-12-14T22:53:43.838465+0000 INFO USER0156_PASSWORD: a******************************a
# 2024-12-14T22:53:43.838976+0000 INFO USER0002_PASSWORD: 9******************************f
# 2024-12-14T22:53:43.839436+0000 INFO USER0039_PASSWORD: 0******************************4
# 2024-12-14T22:53:43.839864+0000 INFO USER0010_PASSWORD: b******************************5
# 2024-12-14T22:53:43.840813+0000 INFO USER0040_PASSWORD: 0******************************9
# 2024-12-14T22:53:43.841289+0000 INFO USER0068_PASSWORD: 7******************************3
# 2024-12-14T22:53:43.845342+0000 INFO USER0195_PASSWORD: 2******************************c
# 2024-12-14T22:53:43.846341+0000 INFO USER0058_PASSWORD: f******************************0
# 2024-12-14T22:53:43.848260+0000 INFO USER0114_PASSWORD: c******************************b
# 2024-12-14T22:53:43.851544+0000 INFO USER0144_PASSWORD: c******************************e
# 2024-12-14T22:53:43.852515+0000 INFO USER0137_PASSWORD: 3******************************c
# 2024-12-14T22:53:43.854510+0000 INFO USER0128_PASSWORD: e******************************c
# 2024-12-14T22:53:43.855825+0000 INFO USER0099_PASSWORD: 2******************************5
# 2024-12-14T22:53:43.856600+0000 INFO USER0110_PASSWORD: a******************************7
# 2024-12-14T22:53:43.857448+0000 INFO USER0192_PASSWORD: 7******************************3
# 2024-12-14T22:53:43.858281+0000 INFO USER0119_PASSWORD: 1******************************2
# 2024-12-14T22:53:43.859934+0000 INFO USER0072_PASSWORD: e******************************d
# 2024-12-14T22:53:43.860564+0000 INFO USER0102_PASSWORD: 0******************************d
# 2024-12-14T22:53:43.861431+0000 INFO USER0139_PASSWORD: 3******************************a
# 2024-12-14T22:53:43.862381+0000 INFO USER0109_PASSWORD: 4******************************1
# 2024-12-14T22:53:43.863609+0000 INFO USER0028_PASSWORD: 8******************************6
# 2024-12-14T22:53:43.864383+0000 INFO USER0185_PASSWORD: 1******************************9
# 2024-12-14T22:53:43.865523+0000 INFO USER0129_PASSWORD: b******************************1
# 2024-12-14T22:53:43.866329+0000 INFO USER0126_PASSWORD: 4******************************0
# 2024-12-14T22:53:43.867283+0000 INFO USER0061_PASSWORD: 6******************************2
# 2024-12-14T22:53:43.867811+0000 INFO USER0004_PASSWORD: 7******************************f
# 2024-12-14T22:53:43.868430+0000 INFO USER0076_PASSWORD: 4******************************8
# 2024-12-14T22:53:43.869144+0000 INFO USER0108_PASSWORD: a******************************7
# 2024-12-14T22:53:43.869771+0000 INFO USER0001_PASSWORD: 9******************************8
# 2024-12-14T22:53:43.871092+0000 INFO USER0168_PASSWORD: c******************************2
# 2024-12-14T22:53:43.871932+0000 INFO USER0020_PASSWORD: 7******************************4
# 2024-12-14T22:53:43.873083+0000 INFO USER0117_PASSWORD: 6******************************a
# 2024-12-14T22:53:43.873884+0000 INFO USER0059_PASSWORD: 2******************************a
# 2024-12-14T22:53:43.874567+0000 INFO USER0056_PASSWORD: 4******************************0
# 2024-12-14T22:53:43.875610+0000 INFO USER0166_PASSWORD: 8******************************d
# 2024-12-14T22:53:43.876133+0000 INFO USER0048_PASSWORD: 5******************************c
# 2024-12-14T22:53:43.877134+0000 INFO USER0024_PASSWORD: 5******************************e
# 2024-12-14T22:53:43.878050+0000 INFO USER0067_PASSWORD: 3******************************0
# 2024-12-14T22:53:43.880262+0000 INFO USER0184_PASSWORD: a******************************1
# 2024-12-14T22:53:43.881530+0000 INFO USER0077_PASSWORD: 6******************************3
# 2024-12-14T22:53:43.882413+0000 INFO USER0157_PASSWORD: 7******************************2
# 2024-12-14T22:53:43.883486+0000 INFO USER0124_PASSWORD: 0******************************2
# 2024-12-14T22:53:43.885469+0000 INFO USER0032_PASSWORD: 0******************************e
# 2024-12-14T22:53:43.886471+0000 INFO USER0147_PASSWORD: c******************************1
# 2024-12-14T22:53:43.887191+0000 INFO USER0075_PASSWORD: 8******************************a
# 2024-12-14T22:53:43.887939+0000 INFO USER0165_PASSWORD: 7******************************c
# 2024-12-14T22:53:43.888819+0000 INFO USER0197_PASSWORD: e******************************a
# 2024-12-14T22:53:43.889692+0000 INFO USER0063_PASSWORD: 6******************************b
# 2024-12-14T22:53:43.890449+0000 INFO USER0138_PASSWORD: 0******************************4
# 2024-12-14T22:53:43.891353+0000 INFO USER0170_PASSWORD: 8******************************2
# 2024-12-14T22:53:43.892268+0000 INFO USER0012_PASSWORD: c******************************5
# 2024-12-14T22:53:43.892795+0000 INFO USER0029_PASSWORD: 9******************************3
# 2024-12-14T22:53:43.894061+0000 INFO USER0005_PASSWORD: e******************************5
# 2024-12-14T22:53:43.894942+0000 INFO USER0022_PASSWORD: 8******************************7
# 2024-12-14T22:53:43.895572+0000 INFO USER0043_PASSWORD: d******************************1
# 2024-12-14T22:53:43.896916+0000 INFO USER0060_PASSWORD: 8******************************f
# 2024-12-14T22:53:43.898333+0000 INFO USER0051_PASSWORD: 2******************************6
# 2024-12-14T22:53:43.899183+0000 INFO USER0035_PASSWORD: 0******************************2
# 2024-12-14T22:53:43.900357+0000 INFO USER0050_PASSWORD: 3******************************1
# 2024-12-14T22:53:43.901118+0000 INFO USER0120_PASSWORD: c******************************b
# 2024-12-14T22:53:43.901876+0000 INFO USER0038_PASSWORD: 9******************************1
# 2024-12-14T22:53:43.902618+0000 INFO USER0130_PASSWORD: b******************************d
# 2024-12-14T22:53:43.903570+0000 INFO USER0187_PASSWORD: 5******************************c
# 2024-12-14T22:53:43.904056+0000 INFO USER0141_PASSWORD: c******************************3
# 2024-12-14T22:53:43.904527+0000 INFO USER0199_PASSWORD: e******************************6
# 2024-12-14T22:53:43.905546+0000 INFO USER0175_PASSWORD: c******************************4
# 2024-12-14T22:53:43.906038+0000 INFO USER0127_PASSWORD: 3******************************c
# 2024-12-14T22:53:43.906481+0000 INFO USER0089_PASSWORD: b******************************e
# 2024-12-14T22:53:43.906939+0000 INFO USER0071_PASSWORD: 7******************************e
# 2024-12-14T22:53:43.907944+0000 INFO USER0062_PASSWORD: 7******************************5
# 2024-12-14T22:53:43.908433+0000 INFO USER0194_PASSWORD: a******************************d
# 2024-12-14T22:53:43.908981+0000 INFO USER0153_PASSWORD: a******************************b
# 2024-12-14T22:53:43.909464+0000 INFO USER0160_PASSWORD: 1******************************0
# 2024-12-14T22:53:43.910572+0000 INFO USER0014_PASSWORD: 4******************************c
# 2024-12-14T22:53:43.912006+0000 INFO USER0155_PASSWORD: 2******************************7
# 2024-12-14T22:53:43.912770+0000 INFO USER0146_PASSWORD: c******************************9
# 2024-12-14T22:53:43.913211+0000 INFO USER0158_PASSWORD: f******************************f
# 2024-12-14T22:53:43.913649+0000 INFO USER0065_PASSWORD: 2******************************4
# 2024-12-14T22:53:43.914487+0000 INFO USER0080_PASSWORD: e******************************c
# 2024-12-14T22:53:43.915006+0000 INFO USER0070_PASSWORD: 7******************************7
# 2024-12-14T22:53:43.915435+0000 INFO USER0045_PASSWORD: 6******************************2
# 2024-12-14T22:53:43.915875+0000 INFO USER0196_PASSWORD: 1******************************5
# 2024-12-14T22:53:43.916855+0000 INFO USER0087_PASSWORD: f******************************8
# 2024-12-14T22:53:43.917339+0000 INFO USER0023_PASSWORD: 5******************************4
# 2024-12-14T22:53:43.917790+0000 INFO USER0055_PASSWORD: 2******************************b
# 2024-12-14T22:53:43.918239+0000 INFO USER0131_PASSWORD: f******************************8
# 2024-12-14T22:53:43.919276+0000 INFO USER0044_PASSWORD: 1******************************0
# 2024-12-14T22:53:43.919778+0000 INFO USER0133_PASSWORD: b******************************7
# 2024-12-14T22:53:43.920231+0000 INFO USER0019_PASSWORD: a******************************2
# 2024-12-14T22:53:43.920683+0000 INFO USER0122_PASSWORD: 0******************************8
# 2024-12-14T22:53:43.921797+0000 INFO USER0172_PASSWORD: f******************************a
# 2024-12-14T22:53:43.922492+0000 INFO USER0180_PASSWORD: e******************************e
# 2024-12-14T22:53:43.923025+0000 INFO USER0007_PASSWORD: 1******************************a
# 2024-12-14T22:53:43.923765+0000 INFO USER0105_PASSWORD: 5******************************c
# 2024-12-14T22:53:43.924170+0000 INFO USER0200_PASSWORD: 1******************************4
# 2024-12-14T22:53:43.924580+0000 INFO USER0017_PASSWORD: 8******************************8
# 2024-12-14T22:53:43.929266+0000 INFO USER0036_PASSWORD: d******************************8
# 2024-12-14T22:53:43.930031+0000 INFO USER0041_PASSWORD: 7******************************7
# 2024-12-14T22:53:43.930967+0000 INFO USER0057_PASSWORD: 5******************************1
# 2024-12-14T22:53:43.932031+0000 INFO USER0145_PASSWORD: 6******************************2
# 2024-12-14T22:53:43.932886+0000 INFO USER0190_PASSWORD: 8******************************7
# 2024-12-14T22:53:43.933374+0000 INFO USER0164_PASSWORD: 2******************************a
# 2024-12-14T22:53:43.933947+0000 INFO USER0118_PASSWORD: 7******************************6
# 2024-12-14T22:53:43.937466+0000 INFO USER0073_PASSWORD: 7******************************5
# 2024-12-14T22:53:43.938355+0000 INFO USER0198_PASSWORD: 5******************************9
# 2024-12-14T22:53:43.940370+0000 INFO USER0066_PASSWORD: 2******************************0
# 2024-12-14T22:53:43.941779+0000 INFO USER0088_PASSWORD: 4******************************2
# 2024-12-14T22:53:43.944251+0000 INFO USER0100_PASSWORD: 5******************************d
# 2024-12-14T22:53:43.946005+0000 INFO USER0009_PASSWORD: f******************************5
# 2024-12-14T22:53:43.946860+0000 INFO USER0094_PASSWORD: 1******************************4
# 2024-12-14T22:53:43.948877+0000 INFO USER0096_PASSWORD: 7******************************b
# 2024-12-14T22:53:43.949496+0000 INFO USER0069_PASSWORD: b******************************a
# 2024-12-14T22:53:43.951554+0000 INFO USER0016_PASSWORD: 7******************************6
# 2024-12-14T22:53:43.952920+0000 INFO USER0097_PASSWORD: 9******************************d
# 2024-12-14T22:53:43.953992+0000 INFO USER0148_PASSWORD: 3******************************6

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()

    reset_users(users, skip_confirm=True, parallel=True)

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"
# Out:
# 2024-12-14T22:53:44.770496+0000 INFO Starting comprehensive reset process for user: user0001
# 2024-12-14T22:53:44.785134+0000 INFO Starting comprehensive reset process for user: user0004
# 2024-12-14T22:53:44.817232+0000 INFO Starting comprehensive reset process for user: user0005
# 2024-12-14T22:53:44.986086+0000 INFO Starting comprehensive reset process for user: user0003
# 2024-12-14T22:53:44.996180+0000 INFO Starting comprehensive reset process for user: user0002
# 2024-12-14T22:53:45.012469+0000 INFO Starting comprehensive reset process for user: user0007
# 2024-12-14T22:53:45.051475+0000 INFO Starting comprehensive reset process for user: user0008
# 2024-12-14T22:53:45.150464+0000 INFO Starting comprehensive reset process for user: user0006
# 2024-12-14T22:53:45.416150+0000 ERROR Error: invalid literal for int() with base 10: '66, 299'
# 2024-12-14T22:53:45.446282+0000 ERROR Error: invalid literal for int() with base 10: '66, 299'
# 2024-12-14T22:53:45.470643+0000 ERROR Error: invalid literal for int() with base 10: '66, 297'
# 2024-12-14T22:53:45.502415+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.512866+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 296'
# 2024-12-14T22:53:45.528865+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.529597+0000 ERROR Error: invalid literal for int() with base 10: '65, 299'
# 2024-12-14T22:53:45.534580+0000 ERROR Error in unfollow_all_users for user0005: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:45.545812+0000 ERROR Error in unfollow_all_users for user0001: invalid literal for int() with base 10: '65, 295'
# 2024-12-14T22:53:45.547913+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.546450+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.550271+0000 INFO Comprehensive reset process completed for user: user0001
# 2024-12-14T22:53:45.556371+0000 INFO Comprehensive reset process completed for user: user0005
# 2024-12-14T22:53:45.556972+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.584894+0000 ERROR Error: invalid literal for int() with base 10: '65, 299'
# 2024-12-14T22:53:45.586387+0000 ERROR Error in unfollow_all_users for user0004: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:45.707681+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.711279+0000 INFO Comprehensive reset process completed for user: user0004
# 2024-12-14T22:53:45.708873+0000 ERROR Error in unfollow_all_users for user0003: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:45.731233+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.716895+0000 ERROR Error: invalid literal for int() with base 10: '65, 299'
# 2024-12-14T22:53:45.744919+0000 INFO Comprehensive reset process completed for user: user0003
# 2024-12-14T22:53:45.752063+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.798768+0000 ERROR Error: invalid literal for int() with base 10: '65, 299'
# 2024-12-14T22:53:45.817166+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.829105+0000 ERROR Error: invalid literal for int() with base 10: '65, 299'
# 2024-12-14T22:53:45.843071+0000 ERROR Error in unfollow_all_users for user0002: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:45.862544+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.872346+0000 ERROR Error in unfollow_all_users for user0007: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:45.874206+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.875911+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '65, 298'
# 2024-12-14T22:53:45.883852+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.893645+0000 INFO Comprehensive reset process completed for user: user0002
# 2024-12-14T22:53:45.893934+0000 ERROR Error in unfollow_all_users for user0006: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:45.903873+0000 INFO Starting comprehensive reset process for user: user0009
# 2024-12-14T22:53:45.904242+0000 INFO Comprehensive reset process completed for user: user0007
# 2024-12-14T22:53:45.906791+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:45.908051+0000 INFO Starting comprehensive reset process for user: user0010
# 2024-12-14T22:53:45.931361+0000 ERROR Error in unfollow_all_users for user0008: invalid literal for int() with base 10: '65, 297'
# 2024-12-14T22:53:46.117636+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:46.120202+0000 INFO Comprehensive reset process completed for user: user0008
# 2024-12-14T22:53:45.984488+0000 INFO Comprehensive reset process completed for user: user0006
# 2024-12-14T22:53:46.250577+0000 INFO Starting comprehensive reset process for user: user0011
# 2024-12-14T22:53:46.255042+0000 INFO Starting comprehensive reset process for user: user0012
# 2024-12-14T22:53:46.539546+0000 INFO Starting comprehensive reset process for user: user0013
# 2024-12-14T22:53:46.588913+0000 ERROR Error: invalid literal for int() with base 10: '65, 299'
# 2024-12-14T22:53:46.600830+0000 INFO Starting comprehensive reset process for user: user0014
# 2024-12-14T22:53:46.620461+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:46.658306+0000 INFO Starting comprehensive reset process for user: user0015
# 2024-12-14T22:53:46.666536+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:46.667254+0000 ERROR Error in unfollow_all_users for user0009: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:46.700651+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:46.678145+0000 INFO Starting comprehensive reset process for user: user0016
# 2024-12-14T22:53:46.708072+0000 INFO Comprehensive reset process completed for user: user0009
# 2024-12-14T22:53:46.731443+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:46.744088+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:46.778971+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:46.829441+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:46.867040+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:46.874383+0000 ERROR Error in unfollow_all_users for user0010: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:46.890309+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:46.891910+0000 INFO Comprehensive reset process completed for user: user0010
# 2024-12-14T22:53:46.895149+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:46.906594+0000 ERROR Error in unfollow_all_users for user0011: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:46.912370+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:46.928063+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:46.930459+0000 ERROR Error in unfollow_all_users for user0012: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:46.931065+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:46.970332+0000 INFO Comprehensive reset process completed for user: user0011
# 2024-12-14T22:53:46.969366+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:46.968551+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:46.977575+0000 ERROR Error in unfollow_all_users for user0013: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:46.985652+0000 INFO Comprehensive reset process completed for user: user0012
# 2024-12-14T22:53:47.001224+0000 ERROR Error in unfollow_all_users for user0014: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:47.011382+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:47.040553+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:47.042605+0000 ERROR Error: invalid literal for int() with base 10: '64, 299'
# 2024-12-14T22:53:47.047604+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:47.054839+0000 INFO Comprehensive reset process completed for user: user0013
# 2024-12-14T22:53:47.068472+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:47.081490+0000 INFO Starting comprehensive reset process for user: user0017
# 2024-12-14T22:53:47.100766+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '64, 298'
# 2024-12-14T22:53:47.106336+0000 INFO Comprehensive reset process completed for user: user0014
# 2024-12-14T22:53:47.117185+0000 INFO Starting comprehensive reset process for user: user0018
# 2024-12-14T22:53:47.168399+0000 ERROR Error in unfollow_all_users for user0015: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:47.218610+0000 ERROR Error in unfollow_all_users for user0016: invalid literal for int() with base 10: '64, 297'
# 2024-12-14T22:53:47.231011+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:47.310530+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:47.319874+0000 INFO Comprehensive reset process completed for user: user0015
# 2024-12-14T22:53:47.320643+0000 INFO Starting comprehensive reset process for user: user0019
# 2024-12-14T22:53:47.323025+0000 INFO Comprehensive reset process completed for user: user0016
# 2024-12-14T22:53:47.415921+0000 INFO Starting comprehensive reset process for user: user0020
# 2024-12-14T22:53:47.538317+0000 INFO Starting comprehensive reset process for user: user0021
# 2024-12-14T22:53:47.549646+0000 ERROR Error: invalid literal for int() with base 10: '63, 299'
# 2024-12-14T22:53:47.549978+0000 INFO Starting comprehensive reset process for user: user0022
# 2024-12-14T22:53:47.641523+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '63, 298'
# 2024-12-14T22:53:47.653204+0000 ERROR Error: invalid literal for int() with base 10: '63, 299'
# 2024-12-14T22:53:47.679296+0000 ERROR Error in unfollow_all_users for user0017: invalid literal for int() with base 10: '63, 297'
# 2024-12-14T22:53:47.681053+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:47.686672+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '63, 298'
# 2024-12-14T22:53:47.692541+0000 INFO Comprehensive reset process completed for user: user0017
# 2024-12-14T22:53:47.694653+0000 INFO Starting comprehensive reset process for user: user0024
# 2024-12-14T22:53:47.713693+0000 INFO Starting comprehensive reset process for user: user0023
# 2024-12-14T22:53:47.720924+0000 ERROR Error in unfollow_all_users for user0018: invalid literal for int() with base 10: '63, 297'
# 2024-12-14T22:53:47.767875+0000 ERROR Error: invalid literal for int() with base 10: '63, 299'
# 2024-12-14T22:53:47.783169+0000 ERROR Error: invalid literal for int() with base 10: '63, 299'
# 2024-12-14T22:53:47.815636+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:47.918827+0000 INFO Comprehensive reset process completed for user: user0018
# 2024-12-14T22:53:47.917704+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '63, 298'
# 2024-12-14T22:53:47.920658+0000 ERROR Error: invalid literal for int() with base 10: '63, 299'
# 2024-12-14T22:53:47.940971+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '63, 298'
# 2024-12-14T22:53:47.961554+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '63, 298'
# 2024-12-14T22:53:47.974693+0000 ERROR Error in unfollow_all_users for user0019: invalid literal for int() with base 10: '63, 297'
# 2024-12-14T22:53:47.991246+0000 ERROR Error: invalid literal for int() with base 10: '63, 299'
# 2024-12-14T22:53:48.013812+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.021724+0000 INFO Comprehensive reset process completed for user: user0019
# 2024-12-14T22:53:48.020966+0000 ERROR Error in unfollow_all_users for user0020: invalid literal for int() with base 10: '63, 297'
# 2024-12-14T22:53:48.037786+0000 ERROR Error in unfollow_all_users for user0021: invalid literal for int() with base 10: '63, 297'
# 2024-12-14T22:53:48.038035+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.038693+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '63, 298'
# 2024-12-14T22:53:48.053056+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.061218+0000 INFO Starting comprehensive reset process for user: user0025
# 2024-12-14T22:53:48.084393+0000 INFO Comprehensive reset process completed for user: user0020
# 2024-12-14T22:53:48.113742+0000 INFO Comprehensive reset process completed for user: user0021
# 2024-12-14T22:53:48.138054+0000 ERROR Error in unfollow_all_users for user0022: invalid literal for int() with base 10: '63, 297'
# 2024-12-14T22:53:48.180664+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.189905+0000 INFO Comprehensive reset process completed for user: user0022
# 2024-12-14T22:53:48.190795+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:48.224385+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:48.346865+0000 INFO Starting comprehensive reset process for user: user0026
# 2024-12-14T22:53:48.256918+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '62, 298'
# 2024-12-14T22:53:48.377570+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '62, 298'
# 2024-12-14T22:53:48.443563+0000 ERROR Error in unfollow_all_users for user0024: invalid literal for int() with base 10: '62, 297'
# 2024-12-14T22:53:48.461385+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.461581+0000 INFO Starting comprehensive reset process for user: user0027
# 2024-12-14T22:53:48.461761+0000 ERROR Error in unfollow_all_users for user0023: invalid literal for int() with base 10: '62, 297'
# 2024-12-14T22:53:48.466864+0000 INFO Comprehensive reset process completed for user: user0024
# 2024-12-14T22:53:48.487939+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.491070+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:48.556232+0000 INFO Comprehensive reset process completed for user: user0023
# 2024-12-14T22:53:48.564921+0000 INFO Starting comprehensive reset process for user: user0029
# 2024-12-14T22:53:48.619706+0000 INFO Starting comprehensive reset process for user: user0028
# 2024-12-14T22:53:48.626143+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '62, 298'
# 2024-12-14T22:53:48.779982+0000 ERROR Error in unfollow_all_users for user0025: invalid literal for int() with base 10: '62, 297'
# 2024-12-14T22:53:48.817915+0000 INFO Starting comprehensive reset process for user: user0030
# 2024-12-14T22:53:48.833762+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:48.855982+0000 INFO Comprehensive reset process completed for user: user0025
# 2024-12-14T22:53:48.865343+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:48.903290+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:48.970687+0000 INFO Starting comprehensive reset process for user: user0031
# 2024-12-14T22:53:48.971629+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '62, 298'
# 2024-12-14T22:53:49.047150+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '62, 298'
# 2024-12-14T22:53:49.109874+0000 ERROR Error in unfollow_all_users for user0026: invalid literal for int() with base 10: '62, 297'
# 2024-12-14T22:53:49.128391+0000 ERROR Error in unfollow_all_users for user0027: invalid literal for int() with base 10: '62, 297'
# 2024-12-14T22:53:49.144112+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:49.134210+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:49.142700+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:49.128697+0000 INFO Starting comprehensive reset process for user: user0032
# 2024-12-14T22:53:49.147970+0000 INFO Comprehensive reset process completed for user: user0027
# 2024-12-14T22:53:49.161774+0000 INFO Comprehensive reset process completed for user: user0026
# 2024-12-14T22:53:49.163405+0000 ERROR Error: invalid literal for int() with base 10: '62, 299'
# 2024-12-14T22:53:49.195532+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:49.221442+0000 ERROR Error: invalid literal for int() with base 10: '61, 299'
# 2024-12-14T22:53:49.299943+0000 ERROR Error in unfollow_all_users for user0029: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:49.379901+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:49.386839+0000 INFO Comprehensive reset process completed for user: user0029
# 2024-12-14T22:53:49.352677+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:49.364869+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:49.426853+0000 INFO Starting comprehensive reset process for user: user0033
# 2024-12-14T22:53:49.478935+0000 ERROR Error in unfollow_all_users for user0028: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:49.464962+0000 ERROR Error: invalid literal for int() with base 10: '61, 299'
# 2024-12-14T22:53:49.486954+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:49.492865+0000 ERROR Error in unfollow_all_users for user0030: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:49.534954+0000 INFO Comprehensive reset process completed for user: user0028
# 2024-12-14T22:53:49.535459+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:49.601705+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:49.684982+0000 INFO Starting comprehensive reset process for user: user0035
# 2024-12-14T22:53:49.685111+0000 INFO Comprehensive reset process completed for user: user0030
# 2024-12-14T22:53:49.685233+0000 ERROR Error in unfollow_all_users for user0031: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:49.880926+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:49.898295+0000 INFO Comprehensive reset process completed for user: user0031
# 2024-12-14T22:53:49.687089+0000 INFO Starting comprehensive reset process for user: user0034
# 2024-12-14T22:53:49.870165+0000 ERROR Error: invalid literal for int() with base 10: '61, 299'
# 2024-12-14T22:53:50.013638+0000 INFO Starting comprehensive reset process for user: user0036
# 2024-12-14T22:53:50.054238+0000 ERROR Error: invalid literal for int() with base 10: '61, 299'
# 2024-12-14T22:53:50.054806+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:50.119657+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:50.179708+0000 ERROR Error in unfollow_all_users for user0033: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:50.182325+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:50.185967+0000 INFO Comprehensive reset process completed for user: user0033
# 2024-12-14T22:53:50.195128+0000 ERROR Error in unfollow_all_users for user0032: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:50.203616+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:50.203365+0000 INFO Starting comprehensive reset process for user: user0037
# 2024-12-14T22:53:50.214562+0000 ERROR Error: invalid literal for int() with base 10: '61, 299'
# 2024-12-14T22:53:50.215085+0000 INFO Comprehensive reset process completed for user: user0032
# 2024-12-14T22:53:50.310497+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '61, 298'
# 2024-12-14T22:53:50.317817+0000 INFO Starting comprehensive reset process for user: user0039
# 2024-12-14T22:53:50.332522+0000 INFO Starting comprehensive reset process for user: user0038
# 2024-12-14T22:53:50.404917+0000 ERROR Error in unfollow_all_users for user0035: invalid literal for int() with base 10: '61, 297'
# 2024-12-14T22:53:50.540311+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:50.467962+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:50.545556+0000 INFO Comprehensive reset process completed for user: user0035
# 2024-12-14T22:53:50.578726+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:50.590708+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:50.663278+0000 ERROR Error in unfollow_all_users for user0034: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:50.669016+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:50.692876+0000 INFO Starting comprehensive reset process for user: user0040
# 2024-12-14T22:53:50.691071+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:50.683409+0000 INFO Starting comprehensive reset process for user: user0041
# 2024-12-14T22:53:50.706621+0000 INFO Comprehensive reset process completed for user: user0034
# 2024-12-14T22:53:50.715152+0000 ERROR Error in unfollow_all_users for user0036: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:50.716517+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:50.725183+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:50.806580+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:50.884650+0000 INFO Comprehensive reset process completed for user: user0036
# 2024-12-14T22:53:50.917705+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:50.918354+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:50.932917+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:50.972648+0000 INFO Starting comprehensive reset process for user: user0042
# 2024-12-14T22:53:50.973903+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:51.005207+0000 ERROR Error in unfollow_all_users for user0039: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:51.048209+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:51.050005+0000 INFO Comprehensive reset process completed for user: user0039
# 2024-12-14T22:53:51.017126+0000 ERROR Error in unfollow_all_users for user0037: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:51.071193+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:51.068311+0000 ERROR Error in unfollow_all_users for user0038: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:51.129414+0000 INFO Comprehensive reset process completed for user: user0037
# 2024-12-14T22:53:51.130912+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:51.160959+0000 ERROR Error: invalid literal for int() with base 10: '60, 299'
# 2024-12-14T22:53:51.161173+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:51.267253+0000 INFO Comprehensive reset process completed for user: user0038
# 2024-12-14T22:53:51.212555+0000 INFO Starting comprehensive reset process for user: user0043
# 2024-12-14T22:53:51.268722+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:51.210582+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '60, 298'
# 2024-12-14T22:53:51.360573+0000 INFO Starting comprehensive reset process for user: user0044
# 2024-12-14T22:53:51.603400+0000 ERROR Error in unfollow_all_users for user0040: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:51.723100+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:51.756754+0000 INFO Comprehensive reset process completed for user: user0040
# 2024-12-14T22:53:51.614853+0000 ERROR Error in unfollow_all_users for user0041: invalid literal for int() with base 10: '60, 297'
# 2024-12-14T22:53:51.784498+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:51.805603+0000 INFO Comprehensive reset process completed for user: user0041
# 2024-12-14T22:53:51.755579+0000 ERROR Error: invalid literal for int() with base 10: '59, 299'
# 2024-12-14T22:53:51.665501+0000 INFO Starting comprehensive reset process for user: user0045
# 2024-12-14T22:53:51.815260+0000 INFO Starting comprehensive reset process for user: user0046
# 2024-12-14T22:53:51.932749+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '59, 298'
# 2024-12-14T22:53:52.045163+0000 ERROR Error: invalid literal for int() with base 10: '59, 299'
# 2024-12-14T22:53:52.083609+0000 INFO Starting comprehensive reset process for user: user0047
# 2024-12-14T22:53:52.101846+0000 ERROR Error in unfollow_all_users for user0042: invalid literal for int() with base 10: '59, 297'
# 2024-12-14T22:53:52.126652+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:52.151783+0000 INFO Comprehensive reset process completed for user: user0042
# 2024-12-14T22:53:52.119489+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '59, 298'
# 2024-12-14T22:53:52.221675+0000 ERROR Error in unfollow_all_users for user0043: invalid literal for int() with base 10: '59, 297'
# 2024-12-14T22:53:52.228192+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:52.238061+0000 INFO Comprehensive reset process completed for user: user0043
# 2024-12-14T22:53:52.369625+0000 ERROR Error: invalid literal for int() with base 10: '59, 299'
# 2024-12-14T22:53:52.412223+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '59, 298'
# 2024-12-14T22:53:52.448935+0000 ERROR Error in unfollow_all_users for user0044: invalid literal for int() with base 10: '59, 297'
# 2024-12-14T22:53:52.461586+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:52.468543+0000 INFO Comprehensive reset process completed for user: user0044
# 2024-12-14T22:53:52.463854+0000 INFO Starting comprehensive reset process for user: user0048
# 2024-12-14T22:53:52.471862+0000 INFO Starting comprehensive reset process for user: user0049
# 2024-12-14T22:53:52.474698+0000 INFO Starting comprehensive reset process for user: user0050
# 2024-12-14T22:53:52.495911+0000 INFO Starting comprehensive reset process for user: user0051
# 2024-12-14T22:53:52.501177+0000 ERROR Error: invalid literal for int() with base 10: '59, 299'
# 2024-12-14T22:53:52.593842+0000 ERROR Error: invalid literal for int() with base 10: '59, 299'
# 2024-12-14T22:53:52.665641+0000 ERROR Error: invalid literal for int() with base 10: '59, 299'
# 2024-12-14T22:53:52.785818+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '59, 298'
# 2024-12-14T22:53:52.807180+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '59, 298'
# 2024-12-14T22:53:52.836601+0000 ERROR Error in unfollow_all_users for user0046: invalid literal for int() with base 10: '59, 297'
# 2024-12-14T22:53:52.844720+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:52.842425+0000 ERROR Error in unfollow_all_users for user0045: invalid literal for int() with base 10: '59, 297'
# 2024-12-14T22:53:52.848604+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:52.852858+0000 INFO Comprehensive reset process completed for user: user0045
# 2024-12-14T22:53:52.843994+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '59, 298'
# 2024-12-14T22:53:52.847808+0000 INFO Comprehensive reset process completed for user: user0046
# 2024-12-14T22:53:52.878047+0000 INFO Starting comprehensive reset process for user: user0052
# 2024-12-14T22:53:52.953994+0000 ERROR Error in unfollow_all_users for user0047: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.074170+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.099544+0000 INFO Comprehensive reset process completed for user: user0047
# 2024-12-14T22:53:53.110905+0000 ERROR Error: invalid literal for int() with base 10: '58, 299'
# 2024-12-14T22:53:53.139151+0000 ERROR Error: invalid literal for int() with base 10: '58, 299'
# 2024-12-14T22:53:53.168363+0000 ERROR Error: invalid literal for int() with base 10: '58, 299'
# 2024-12-14T22:53:53.174083+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '58, 298'
# 2024-12-14T22:53:53.199222+0000 ERROR Error: invalid literal for int() with base 10: '58, 299'
# 2024-12-14T22:53:53.231613+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '58, 298'
# 2024-12-14T22:53:53.232270+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '58, 298'
# 2024-12-14T22:53:53.234991+0000 INFO Starting comprehensive reset process for user: user0053
# 2024-12-14T22:53:53.236347+0000 ERROR Error in unfollow_all_users for user0051: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.237848+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '58, 298'
# 2024-12-14T22:53:53.248962+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.276623+0000 ERROR Error in unfollow_all_users for user0050: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.326999+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.330546+0000 INFO Comprehensive reset process completed for user: user0050
# 2024-12-14T22:53:53.317234+0000 ERROR Error in unfollow_all_users for user0048: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.276860+0000 ERROR Error in unfollow_all_users for user0049: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.314119+0000 INFO Comprehensive reset process completed for user: user0051
# 2024-12-14T22:53:53.381224+0000 INFO Starting comprehensive reset process for user: user0054
# 2024-12-14T22:53:53.392964+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.413004+0000 INFO Starting comprehensive reset process for user: user0055
# 2024-12-14T22:53:53.413712+0000 ERROR Error: invalid literal for int() with base 10: '58, 299'
# 2024-12-14T22:53:53.416859+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.533543+0000 INFO Comprehensive reset process completed for user: user0048
# 2024-12-14T22:53:53.610572+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '58, 298'
# 2024-12-14T22:53:53.610725+0000 INFO Comprehensive reset process completed for user: user0049
# 2024-12-14T22:53:53.665882+0000 ERROR Error: invalid literal for int() with base 10: '58, 299'
# 2024-12-14T22:53:53.672038+0000 ERROR Error in unfollow_all_users for user0052: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.689901+0000 INFO Starting comprehensive reset process for user: user0056
# 2024-12-14T22:53:53.729383+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.769235+0000 INFO Comprehensive reset process completed for user: user0052
# 2024-12-14T22:53:53.736416+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '58, 298'
# 2024-12-14T22:53:53.855174+0000 INFO Starting comprehensive reset process for user: user0057
# 2024-12-14T22:53:53.909146+0000 ERROR Error in unfollow_all_users for user0053: invalid literal for int() with base 10: '58, 297'
# 2024-12-14T22:53:53.924506+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:53.931846+0000 INFO Comprehensive reset process completed for user: user0053
# 2024-12-14T22:53:53.977068+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:53.986507+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.034581+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '57, 298'
# 2024-12-14T22:53:54.074349+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '57, 298'
# 2024-12-14T22:53:54.084545+0000 ERROR Error in unfollow_all_users for user0054: invalid literal for int() with base 10: '57, 297'
# 2024-12-14T22:53:54.099145+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:54.105758+0000 INFO Starting comprehensive reset process for user: user0058
# 2024-12-14T22:53:54.106549+0000 INFO Comprehensive reset process completed for user: user0054
# 2024-12-14T22:53:54.122911+0000 ERROR Error in unfollow_all_users for user0055: invalid literal for int() with base 10: '57, 297'
# 2024-12-14T22:53:54.144806+0000 INFO Starting comprehensive reset process for user: user0059
# 2024-12-14T22:53:54.145241+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.163893+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:54.236024+0000 INFO Starting comprehensive reset process for user: user0060
# 2024-12-14T22:53:54.279712+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '57, 298'
# 2024-12-14T22:53:54.287574+0000 INFO Comprehensive reset process completed for user: user0055
# 2024-12-14T22:53:54.339082+0000 INFO Starting comprehensive reset process for user: user0061
# 2024-12-14T22:53:54.356929+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.390842+0000 ERROR Error in unfollow_all_users for user0056: invalid literal for int() with base 10: '57, 297'
# 2024-12-14T22:53:54.427510+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:54.483775+0000 INFO Comprehensive reset process completed for user: user0056
# 2024-12-14T22:53:54.444443+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '57, 298'
# 2024-12-14T22:53:54.539428+0000 INFO Starting comprehensive reset process for user: user0062
# 2024-12-14T22:53:54.572741+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.579170+0000 ERROR Error in unfollow_all_users for user0057: invalid literal for int() with base 10: '57, 297'
# 2024-12-14T22:53:54.651203+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:54.600676+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.655984+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '57, 298'
# 2024-12-14T22:53:54.678613+0000 INFO Comprehensive reset process completed for user: user0057
# 2024-12-14T22:53:54.707370+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '57, 298'
# 2024-12-14T22:53:54.717542+0000 ERROR Error in unfollow_all_users for user0058: invalid literal for int() with base 10: '57, 297'
# 2024-12-14T22:53:54.720840+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.727784+0000 INFO Starting comprehensive reset process for user: user0063
# 2024-12-14T22:53:54.754341+0000 ERROR Error in unfollow_all_users for user0059: invalid literal for int() with base 10: '57, 297'
# 2024-12-14T22:53:54.819280+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:54.840965+0000 INFO Comprehensive reset process completed for user: user0059
# 2024-12-14T22:53:54.761675+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:54.818142+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:54.762587+0000 ERROR Error: invalid literal for int() with base 10: '57, 299'
# 2024-12-14T22:53:54.889750+0000 INFO Comprehensive reset process completed for user: user0058
# 2024-12-14T22:53:54.890309+0000 INFO Starting comprehensive reset process for user: user0064
# 2024-12-14T22:53:54.945392+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:54.954920+0000 ERROR Error in unfollow_all_users for user0061: invalid literal for int() with base 10: '56, 297'
# 2024-12-14T22:53:55.043888+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.003077+0000 ERROR Error: invalid literal for int() with base 10: '56, 299'
# 2024-12-14T22:53:55.046580+0000 INFO Comprehensive reset process completed for user: user0061
# 2024-12-14T22:53:55.069636+0000 ERROR Error in unfollow_all_users for user0060: invalid literal for int() with base 10: '56, 297'
# 2024-12-14T22:53:55.116730+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.119079+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:55.148686+0000 INFO Comprehensive reset process completed for user: user0060
# 2024-12-14T22:53:55.158370+0000 INFO Starting comprehensive reset process for user: user0065
# 2024-12-14T22:53:55.163808+0000 INFO Starting comprehensive reset process for user: user0066
# 2024-12-14T22:53:55.194974+0000 ERROR Error in unfollow_all_users for user0062: invalid literal for int() with base 10: '56, 297'
# 2024-12-14T22:53:55.250373+0000 ERROR Error: invalid literal for int() with base 10: '56, 299'
# 2024-12-14T22:53:55.340625+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.374706+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:55.375350+0000 INFO Comprehensive reset process completed for user: user0062
# 2024-12-14T22:53:55.416180+0000 INFO Starting comprehensive reset process for user: user0068
# 2024-12-14T22:53:55.425440+0000 ERROR Error: invalid literal for int() with base 10: '56, 299'
# 2024-12-14T22:53:55.426013+0000 ERROR Error in unfollow_all_users for user0063: invalid literal for int() with base 10: '56, 297'
# 2024-12-14T22:53:55.496149+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.526183+0000 INFO Comprehensive reset process completed for user: user0063
# 2024-12-14T22:53:55.426228+0000 INFO Starting comprehensive reset process for user: user0067
# 2024-12-14T22:53:55.480651+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:55.588979+0000 ERROR Error: invalid literal for int() with base 10: '56, 299'
# 2024-12-14T22:53:55.594323+0000 ERROR Error in unfollow_all_users for user0064: invalid literal for int() with base 10: '56, 297'
# 2024-12-14T22:53:55.668954+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.690190+0000 INFO Comprehensive reset process completed for user: user0064
# 2024-12-14T22:53:55.676395+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:55.690025+0000 ERROR Error: invalid literal for int() with base 10: '56, 299'
# 2024-12-14T22:53:55.637585+0000 INFO Starting comprehensive reset process for user: user0069
# 2024-12-14T22:53:55.738589+0000 ERROR Error in unfollow_all_users for user0065: invalid literal for int() with base 10: '56, 297'
# 2024-12-14T22:53:55.796091+0000 INFO Starting comprehensive reset process for user: user0070
# 2024-12-14T22:53:55.796590+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.811499+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 298'
# 2024-12-14T22:53:55.821197+0000 ERROR Error: invalid literal for int() with base 10: '56, 299'
# 2024-12-14T22:53:55.848491+0000 INFO Comprehensive reset process completed for user: user0065
# 2024-12-14T22:53:55.919737+0000 ERROR Error in unfollow_all_users for user0066: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:55.989637+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:55.971360+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '55, 298'
# 2024-12-14T22:53:55.995913+0000 INFO Comprehensive reset process completed for user: user0066
# 2024-12-14T22:53:56.010398+0000 ERROR Error: invalid literal for int() with base 10: '55, 299'
# 2024-12-14T22:53:56.011322+0000 INFO Starting comprehensive reset process for user: user0071
# 2024-12-14T22:53:56.038832+0000 ERROR Error in unfollow_all_users for user0068: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:56.079259+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '55, 298'
# 2024-12-14T22:53:56.110252+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:56.137132+0000 INFO Starting comprehensive reset process for user: user0072
# 2024-12-14T22:53:56.162070+0000 INFO Comprehensive reset process completed for user: user0068
# 2024-12-14T22:53:56.207022+0000 ERROR Error: invalid literal for int() with base 10: '55, 299'
# 2024-12-14T22:53:56.235863+0000 ERROR Error in unfollow_all_users for user0067: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:56.273238+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:56.272838+0000 ERROR Error: invalid literal for int() with base 10: '55, 299'
# 2024-12-14T22:53:56.243838+0000 INFO Starting comprehensive reset process for user: user0073
# 2024-12-14T22:53:56.284216+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '55, 298'
# 2024-12-14T22:53:56.301268+0000 INFO Comprehensive reset process completed for user: user0067
# 2024-12-14T22:53:56.345161+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '55, 298'
# 2024-12-14T22:53:56.345428+0000 INFO Starting comprehensive reset process for user: user0074
# 2024-12-14T22:53:56.377701+0000 ERROR Error in unfollow_all_users for user0070: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:56.412616+0000 ERROR Error in unfollow_all_users for user0069: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:56.468178+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:56.513823+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:56.516702+0000 INFO Comprehensive reset process completed for user: user0070
# 2024-12-14T22:53:56.522569+0000 INFO Comprehensive reset process completed for user: user0069
# 2024-12-14T22:53:56.522736+0000 INFO Starting comprehensive reset process for user: user0075
# 2024-12-14T22:53:56.554332+0000 ERROR Error: invalid literal for int() with base 10: '55, 299'
# 2024-12-14T22:53:56.616923+0000 ERROR Error: invalid literal for int() with base 10: '55, 299'
# 2024-12-14T22:53:56.694934+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '55, 298'
# 2024-12-14T22:53:56.712984+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '55, 298'
# 2024-12-14T22:53:56.749957+0000 INFO Starting comprehensive reset process for user: user0076
# 2024-12-14T22:53:56.775064+0000 ERROR Error in unfollow_all_users for user0072: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:56.786629+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:56.787036+0000 ERROR Error in unfollow_all_users for user0071: invalid literal for int() with base 10: '55, 297'
# 2024-12-14T22:53:56.787521+0000 ERROR Error: invalid literal for int() with base 10: '54, 299'
# 2024-12-14T22:53:56.788952+0000 ERROR Error: invalid literal for int() with base 10: '54, 299'
# 2024-12-14T22:53:56.805126+0000 INFO Comprehensive reset process completed for user: user0072
# 2024-12-14T22:53:56.822955+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:53:56.840033+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '54, 298'
# 2024-12-14T22:53:56.859104+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '54, 298'
# 2024-12-14T22:53:56.883711+0000 INFO Comprehensive reset process completed for user: user0071
# ...
# 2024-12-14T22:54:14.497885+0000 ERROR Error: invalid literal for int() with base 10: '38, 299'
# 2024-12-14T22:54:14.624997+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '38, 298'
# 2024-12-14T22:54:14.766468+0000 ERROR Error in unfollow_all_users for user0176: invalid literal for int() with base 10: '38, 297'
# 2024-12-14T22:54:14.767656+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:14.769606+0000 ERROR Error: invalid literal for int() with base 10: '38, 299'
# 2024-12-14T22:54:14.775718+0000 ERROR Error: invalid literal for int() with base 10: '38, 299'
# 2024-12-14T22:54:14.782113+0000 INFO Comprehensive reset process completed for user: user0176
# 2024-12-14T22:54:14.785295+0000 INFO Starting comprehensive reset process for user: user0182
# 2024-12-14T22:54:14.824116+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '38, 298'
# 2024-12-14T22:54:14.824509+0000 ERROR Error: invalid literal for int() with base 10: '38, 299'
# 2024-12-14T22:54:14.830403+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '38, 298'
# 2024-12-14T22:54:14.980502+0000 INFO Starting comprehensive reset process for user: user0183
# 2024-12-14T22:54:14.983254+0000 ERROR Error in unfollow_all_users for user0177: invalid literal for int() with base 10: '38, 297'
# 2024-12-14T22:54:14.991506+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '38, 298'
# 2024-12-14T22:54:15.014953+0000 ERROR Error: invalid literal for int() with base 10: '38, 299'
# 2024-12-14T22:54:15.023683+0000 ERROR Error in unfollow_all_users for user0178: invalid literal for int() with base 10: '38, 297'
# 2024-12-14T22:54:15.037429+0000 ERROR Error: invalid literal for int() with base 10: '38, 299'
# 2024-12-14T22:54:15.054350+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.101934+0000 INFO Comprehensive reset process completed for user: user0177
# 2024-12-14T22:54:15.094692+0000 ERROR Error in unfollow_all_users for user0179: invalid literal for int() with base 10: '38, 297'
# 2024-12-14T22:54:15.092696+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.103946+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '38, 298'
# 2024-12-14T22:54:15.117061+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.194110+0000 INFO Comprehensive reset process completed for user: user0179
# 2024-12-14T22:54:15.151798+0000 INFO Comprehensive reset process completed for user: user0178
# 2024-12-14T22:54:15.117617+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '38, 298'
# 2024-12-14T22:54:15.235993+0000 ERROR Error in unfollow_all_users for user0181: invalid literal for int() with base 10: '37, 297'
# 2024-12-14T22:54:15.319068+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.312784+0000 ERROR Error: invalid literal for int() with base 10: '37, 299'
# 2024-12-14T22:54:15.320915+0000 INFO Starting comprehensive reset process for user: user0184
# 2024-12-14T22:54:15.329634+0000 INFO Comprehensive reset process completed for user: user0181
# 2024-12-14T22:54:15.348693+0000 ERROR Error in unfollow_all_users for user0180: invalid literal for int() with base 10: '37, 297'
# 2024-12-14T22:54:15.377701+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '37, 298'
# 2024-12-14T22:54:15.423134+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.439025+0000 ERROR Error: invalid literal for int() with base 10: '37, 299'
# 2024-12-14T22:54:15.439352+0000 INFO Starting comprehensive reset process for user: user0185
# 2024-12-14T22:54:15.483917+0000 INFO Comprehensive reset process completed for user: user0180
# 2024-12-14T22:54:15.529341+0000 ERROR Error in unfollow_all_users for user0183: invalid literal for int() with base 10: '37, 297'
# 2024-12-14T22:54:15.643914+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.644764+0000 INFO Comprehensive reset process completed for user: user0183
# 2024-12-14T22:54:15.640517+0000 INFO Starting comprehensive reset process for user: user0186
# 2024-12-14T22:54:15.655276+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '37, 298'
# 2024-12-14T22:54:15.869001+0000 INFO Starting comprehensive reset process for user: user0187
# 2024-12-14T22:54:15.910248+0000 ERROR Error in unfollow_all_users for user0182: invalid literal for int() with base 10: '37, 297'
# 2024-12-14T22:54:15.925031+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:15.955215+0000 INFO Comprehensive reset process completed for user: user0182
# 2024-12-14T22:54:15.940760+0000 INFO Starting comprehensive reset process for user: user0188
# 2024-12-14T22:54:16.001709+0000 ERROR Error: invalid literal for int() with base 10: '37, 299'
# 2024-12-14T22:54:16.084724+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '37, 298'
# 2024-12-14T22:54:16.188201+0000 ERROR Error: invalid literal for int() with base 10: '37, 299'
# 2024-12-14T22:54:16.195550+0000 ERROR Error in unfollow_all_users for user0184: invalid literal for int() with base 10: '37, 297'
# 2024-12-14T22:54:16.202783+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:16.203295+0000 INFO Comprehensive reset process completed for user: user0184
# 2024-12-14T22:54:16.199414+0000 INFO Starting comprehensive reset process for user: user0189
# 2024-12-14T22:54:16.202039+0000 INFO Starting comprehensive reset process for user: user0190
# 2024-12-14T22:54:16.231129+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '37, 298'
# 2024-12-14T22:54:16.357429+0000 ERROR Error: invalid literal for int() with base 10: '37, 299'
# 2024-12-14T22:54:16.508837+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:16.509833+0000 ERROR Error in unfollow_all_users for user0185: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:16.523643+0000 ERROR Error: invalid literal for int() with base 10: '36, 299'
# 2024-12-14T22:54:16.523858+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:16.527441+0000 INFO Comprehensive reset process completed for user: user0185
# 2024-12-14T22:54:16.524228+0000 INFO Starting comprehensive reset process for user: user0191
# 2024-12-14T22:54:16.546524+0000 ERROR Error in unfollow_all_users for user0186: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:16.556066+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:16.575429+0000 INFO Comprehensive reset process completed for user: user0186
# 2024-12-14T22:54:16.547067+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:16.547534+0000 ERROR Error: invalid literal for int() with base 10: '36, 299'
# 2024-12-14T22:54:16.732076+0000 ERROR Error in unfollow_all_users for user0187: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:16.753946+0000 ERROR Error: invalid literal for int() with base 10: '36, 299'
# 2024-12-14T22:54:16.761654+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:16.768971+0000 INFO Starting comprehensive reset process for user: user0192
# 2024-12-14T22:54:16.770533+0000 INFO Comprehensive reset process completed for user: user0187
# 2024-12-14T22:54:16.793360+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:16.799731+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:16.821777+0000 ERROR Error: invalid literal for int() with base 10: '36, 299'
# 2024-12-14T22:54:16.903853+0000 ERROR Error in unfollow_all_users for user0189: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:16.930958+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:16.955138+0000 INFO Comprehensive reset process completed for user: user0189
# 2024-12-14T22:54:16.951420+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:16.953934+0000 INFO Starting comprehensive reset process for user: user0194
# 2024-12-14T22:54:16.953263+0000 ERROR Error in unfollow_all_users for user0188: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:17.004593+0000 INFO Starting comprehensive reset process for user: user0193
# 2024-12-14T22:54:17.086009+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:17.169526+0000 INFO Comprehensive reset process completed for user: user0188
# 2024-12-14T22:54:17.133398+0000 ERROR Error: invalid literal for int() with base 10: '36, 299'
# 2024-12-14T22:54:17.105532+0000 ERROR Error in unfollow_all_users for user0190: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:17.240947+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:17.256073+0000 INFO Comprehensive reset process completed for user: user0190
# 2024-12-14T22:54:17.319322+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:17.342698+0000 ERROR Error: invalid literal for int() with base 10: '36, 299'
# 2024-12-14T22:54:17.438876+0000 ERROR Error in unfollow_all_users for user0191: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:17.452573+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:17.460386+0000 INFO Comprehensive reset process completed for user: user0191
# 2024-12-14T22:54:17.452377+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 298'
# 2024-12-14T22:54:17.451927+0000 INFO Starting comprehensive reset process for user: user0195
# 2024-12-14T22:54:17.501127+0000 INFO Starting comprehensive reset process for user: user0196
# 2024-12-14T22:54:17.528529+0000 ERROR Error in unfollow_all_users for user0192: invalid literal for int() with base 10: '36, 297'
# 2024-12-14T22:54:17.648548+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:17.691210+0000 INFO Comprehensive reset process completed for user: user0192
# 2024-12-14T22:54:17.784643+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:17.905710+0000 INFO Starting comprehensive reset process for user: user0197
# 2024-12-14T22:54:17.925613+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:17.956711+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:17.989548+0000 INFO Starting comprehensive reset process for user: user0198
# 2024-12-14T22:54:18.026481+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.048677+0000 ERROR Error in unfollow_all_users for user0193: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.097618+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.095946+0000 ERROR Error in unfollow_all_users for user0194: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.116314+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.104839+0000 INFO Comprehensive reset process completed for user: user0193
# 2024-12-14T22:54:18.137420+0000 INFO Comprehensive reset process completed for user: user0194
# 2024-12-14T22:54:18.137019+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:18.167868+0000 INFO Starting comprehensive reset process for user: user0199
# 2024-12-14T22:54:18.183882+0000 INFO Starting comprehensive reset process for user: user0200
# 2024-12-14T22:54:18.184408+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.191301+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:18.285887+0000 ERROR Error in unfollow_all_users for user0195: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.292354+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.299718+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.310442+0000 INFO Comprehensive reset process completed for user: user0195
# 2024-12-14T22:54:18.319143+0000 ERROR Error in unfollow_all_users for user0196: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.323852+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.324875+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:18.326289+0000 INFO Comprehensive reset process completed for user: user0196
# 2024-12-14T22:54:18.333128+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:18.345631+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.354647+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.367787+0000 ERROR Error in unfollow_all_users for user0197: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.371932+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.369316+0000 ERROR Error in unfollow_all_users for user0198: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.384543+0000 INFO Comprehensive reset process completed for user: user0197
# 2024-12-14T22:54:18.387475+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.406982+0000 INFO Comprehensive reset process completed for user: user0198
# 2024-12-14T22:54:18.405490+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:18.423876+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.431710+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# 2024-12-14T22:54:18.437342+0000 ERROR Error in unfollow_all_users for user0199: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.438483+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.440708+0000 INFO Comprehensive reset process completed for user: user0199
# 2024-12-14T22:54:18.443148+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 298'
# 2024-12-14T22:54:18.458492+0000 ERROR Error in unfollow_all_users for user0200: invalid literal for int() with base 10: '35, 297'
# 2024-12-14T22:54:18.459792+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2024-12-14T22:54:18.460463+0000 INFO Comprehensive reset process completed for user: user0200
# 2024-12-14T22:54:18.709498+0000 ERROR Error: invalid literal for int() with base 10: '35, 297'

# %% [markdown]
# ## Set LLM and embedding model

# %%
pwd
# Out:
# '/workspaces/mastodon-sim-2/notebooks'

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.chdir("../../mastodon-sim/")

# %%
os.chdir("notebooks/")

# %%
MODEL_NAME = "ollama"
# MODEL_NAME = "gpt-4o-mini"
# MODEL_NAME = "sonnet"

if "ollama" in MODEL_NAME:
    model = ollama_model.OllamaLanguageModel(model_name="gemma2:27b")
elif "gpt" in MODEL_NAME:
    GPT_API_KEY = os.getenv("OPENAI_API_KEY")
    if not GPT_API_KEY:
        raise ValueError("GPT_API_KEY is required.")
    model = gpt_model.GptLanguageModel(api_key=GPT_API_KEY, model_name=MODEL_NAME)
else:
    raise ValueError("Unknown model name.")

# %%
def write_agent_config_for_independent_sim(agent_config_filename):
    agent_names = [
        "Bill Fredrickson",
        "Maria Gutierrez",
        "Glenn Patterson",
        "Denise Schmidt",
        "Roger Davis",
        "Erica Fitzgerald",
        "Liam Schwartz",
        "Olivia Thompson",
        "Robert Johnson",
        "Janet Thompson",
        "William Davis",
        "Jessica Nguyen",
        "Mark Rodriguez",
        "Emily Jacobs",
        "Ethan Lee",
        "Sophia Patel",
        "Ryan O'Connor",
        "Maggie Chen",
        "Lucas Kim",
        "Nina Patel",
    ]
    genders = [
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
    ]
    big5 = [
        [3, 8, 6, 5, 4],
        [9, 7, 8, 8, 5],
        [1, 5, 7, 2, 9],
        [1, 6, 8, 2, 7],
        [2, 3, 7, 2, 8],
        [8, 6, 9, 3, 7],
        [8, 5, 8, 3, 7],
        [5, 6, 9, 2, 8],
        [5, 7, 4, 6, 5],
        [6, 7, 5, 7, 4],
        [4, 6, 5, 6, 4],
        [7, 6, 5, 7, 5],
        [6, 7, 5, 7, 4],
        [7, 6, 5, 8, 6],
        [6, 8, 6, 6, 4],
        [7, 8, 6, 7, 4],
        [5, 7, 5, 6, 5],
        [6, 7, 6, 8, 4],
        [8, 6, 5, 6, 5],
        [7, 8, 7, 8, 4],
    ]
    big5_keys = ["openness", "conscientiousness", "extraversion", "agreeableness", "neuroticism"]
    candidate_goal = "Win the election and become the mayor of Storhampton."
    active_voter_goal = "Have a good day and vote in the election."
    active_voter_context = "doesn't care about the environment, only about having a stable job"
    Marias_policy_proposals = [
        "increasing environmental regulation of local industries to improve the health of the local environment"
    ]
    Bills_policy_proposals = [
        "lowering taxes on local industries to save jobs",
        "providing subsidies to attract green industries and create jobs to help grow the economy",
    ]
    agent_config = {}
    agent_config["agents"] = []
    for ait, agent_name in enumerate(agent_names):
        agent_dict = {}
        agent_dict["name"] = agent_name
        agent_dict["gender"] = genders[ait]
        agent_dict["traits"] = dict(zip(big5_keys, big5[ait]))
        if ait < 2:
            agent_dict["role"] = "candidate"
            agent_dict["goal"] = candidate_goal
            if agent_dict["name"] == "Maria Gutierrez":
                agent_dict["policy_proposals"] = Marias_policy_proposals
            else:
                agent_dict["policy_proposals"] = Bills_policy_proposals
            agent_dict["context"] = ""
        else:
            agent_dict["role"] = "active_voter"
            agent_dict["context"] = active_voter_context
            agent_dict["goal"] = active_voter_goal
        agent_dict["party"] = ""
        agent_dict["seed_toot"] = ""
        agent_config["agents"].append(agent_dict)
    agent_config["shared_memories_template"] = [
        "You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.",
        "Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.",
        "Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.",
        "Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.",
    ]
    agent_config["mastodon_usage_instructions"] = [
        "To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).",
        "Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.",
        "Your home timeline shows toots from people you follow and boosted (reblogged) content.",
        "You can reply to toots, creating threaded conversations.",
        "Favorite (like) toots to show appreciation or save them for later.",
        "Boost (reblog) toots to share them with your followers.",
        "You can mention other users in your toots using their @username.",
        "Follow other users to see their public and unlisted toots in your home timeline.",
        "You can unfollow users if you no longer wish to see their content.",
        "Your profile can be customized with a display name and bio.",
        "You can block users to prevent them from seeing your content or interacting with you.",
        "Unblocking a user reverses the effects of blocking.",
    ]
    agent_config["num_agents"] = len(agent_names)

    # Convert and write JSON object to file
    with open(agent_config_filename, "w") as outfile:
        json.dump(agent_config, outfile, indent=4)


agent_config_filename = "independent_configs_test1_Bill_bias.json"
write_agent_config_for_independent_sim(agent_config_filename)

# %%
import json

# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# with open('agents_data.json', 'r') as file:
with open(agent_config_filename, "r") as file:
    data = json.load(file)
data["candidate_info"] = []
for agent in data["agents"]:
    if agent["role"] == "candidate":
        candidate_info = f"{agent['name']} campaigns on {' and '.join(agent['policy_proposals'])}."
        data["candidate_info"].append(candidate_info)
        agent["context"] = agent["context"] + candidate_info
    else:
        agent["context"] = f"{agent['name']} is a person who {agent['context']}"
# Out:
# /opt/mastodon-sim-env/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = (
    data["shared_memories_template"] + data["candidate_info"] + data["mastodon_usage_instructions"]
)

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Storhampton, a town of 2,500 residents founded in the early 1800s, is grappling with economic and social challenges as it transitions from an industrial center to a more diversified economy. The upcoming mayoral election highlights these tensions, with candidates Fredrickson and Gutierrez offering contrasting visions for the town's future.
#
# Fredrickson focuses on preserving traditional industries through tax breaks and subsidies for green jobs. Gutierrez emphasizes stricter environmental regulations to improve public health. This debate has spilled onto social media platforms like Mastodon, where residents passionately engage in discussions about the candidates and their platforms.
#
# Mastodon, a decentralized social network, allows users to share longer "toots" (up to 500 characters) and participate in threaded conversations. Users can follow others, boost content, and customize their profiles. The platform's structure fosters community engagement and in-depth dialogue.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=30)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME, step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# All players get the same `measurements` object.
measurements = measurements_lib.Measurements()

# %%
# Build agent function


def build_agent(
    agent_config, measurements: measurements_lib.Measurements, player_names: list[str]
) -> tuple:
    """Build an agent based on the given configuration."""
    mem = formative_memory_factory.make_memories(agent_config)

    instructions = generic_components.constant.ConstantComponent(
        state=(
            f"The instructions for how to play the role of {agent_config.name} are as "
            "follows. This is a social science experiment studying how well you "
            f"play the role of a character named {agent_config.name}. The experiment "
            "is structured as a tabletop roleplaying game (like dungeons and "
            "dragons). However, this is a serious social science experiment and "
            "simulation, not just a game. The goal is to be realistic. It is "
            f"important to play the role of a person like {agent_config.name} as "
            "accurately as possible, i.e., by responding in ways that you think "
            f"it is likely a person like {agent_config.name} would respond, and taking "
            f"into account all information about {agent_config.name} that you have. "
            "You will control just this one character. The game master will describe "
            "the current situation, and based on that information, you will suggest "
            "actions for your character. The game master will track the state of the "
            "world and keep it consistent as time passes in the simulation and as "
            "participants take actions and change things in their world. This experiment "
            "need not be fun for the participants. Always use third-person "
            "limited perspective, even when speaking directly to the game master."
        ),
        name="role playing instructions\n",
    )

    election_information = generic_components.constant.ConstantComponent(
        state=("\n".join(data["candidate_info"])), name="critical election information\n"
    )

    time = generic_components.report_function.ReportFunction(
        name="Current time",
        function=clock.current_time_interval_str,
    )

    somatic_state = components.somatic_state.SomaticState(model, mem, agent_config.name, clock.now)
    identity = components.identity.SimIdentity(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
    )

    current_obs = components.observation.Observation(
        agent_name=agent_config.name,
        clock_now=clock.now,
        memory=mem,
        timeframe=time_step * 1,
        component_name="current observations",
    )
    summary_obs = components.observation.ObservationSummary(
        agent_name=agent_config.name,
        model=model,
        clock_now=clock.now,
        memory=mem,
        timeframe_delta_from=datetime.timedelta(hours=4),
        timeframe_delta_until=time_step * 1,
        components=[identity],
        component_name="summary of observations",
    )

    self_perception = components.self_perception.SelfPerception(
        name=f"answer to what kind of person is {agent_config.name}",
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
    )
    relevant_memories = components.all_similar_memories.AllSimilarMemories(
        name="relevant memories",
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        components=[summary_obs, self_perception],
        clock_now=clock.now,
        num_memories_to_retrieve=10,
    )

    situation_perception = components.situation_perception.SituationPerception(
        name=(f"answer to what kind of situation is {agent_config.name} in " + "right now"),
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        components=[current_obs, somatic_state, summary_obs],
        clock_now=clock.now,
    )
    person_by_situation = components.person_by_situation.PersonBySituation(
        name=(
            f"answer to what would a person like {agent_config.name} do in a "
            + "situation like this"
        ),
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
        components=[self_perception, situation_perception],
        verbose=True,
    )
    persona = components.sequential.Sequential(
        name="persona",
        components=[
            self_perception,
            situation_perception,
            person_by_situation,
        ],
    )

    reflection = components.dialectical_reflection.DialecticalReflection(
        name="reflection",
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        intuition_components=[self_perception],
        thinking_components=[persona],
        clock_now=clock.now,
        num_memories_to_retrieve=3,
        verbose=True,
    )

    initial_goal_component = generic_components.constant.ConstantComponent(
        state=agent_config.goal, name="overarching goal"
    )

    plan = components.plan.SimPlan(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
        components=[instructions, identity, initial_goal_component, somatic_state, persona],
        goal=initial_goal_component,
        verbose=False,
    )

    goal_metric = goal_achievement.GoalAchievementMetric(
        model=model,
        player_name=agent_config.name,
        player_goal=agent_config.goal,
        clock=clock,
        name="Goal Achievement",
        measurements=measurements,
        channel="goal_achievement",
        verbose=True,
    )
    morality_metric = common_sense_morality.CommonSenseMoralityMetric(
        model=model,
        player_name=agent_config.name,
        clock=clock,
        name="Morality",
        verbose=True,
        measurements=measurements,
        channel="common_sense_morality",
    )

    agent = basic_agent.BasicAgent(
        model=model,
        agent_name=agent_config.name,
        clock=clock,
        verbose=True,
        components=[
            instructions,
            election_information,
            identity,
            persona,
            plan,
            somatic_state,
            summary_obs,
            current_obs,
            relevant_memories,
            reflection,
            time,
            goal_metric,
            morality_metric,
        ],
        update_interval=time_step,
    )

    # reputation_metric = opinion_of_others.OpinionOfOthersMetric(
    #     model=model,
    #     player_name=agent_config.name,
    #     player_names=player_names,
    #     context_fn=agent.state,
    #     clock=clock,
    #     name="Opinion",
    #     verbose=True,
    #     measurements=measurements,
    #     channel="opinion_of_others",
    #     question="What is {opining_player}'s opinion of {of_player}?",
    # )
    # agent.add_component(reputation_metric)

    return agent, mem

# %%
from concordia.typing import entity
from concordia.typing import agent

DEFAULT_CALL_TO_SPEECH = (
    "Given the above, what is {name} likely to say next? Respond in"
    ' the format `{name} -- "..."` For example, '
    'Cristina -- "Hello! Mighty fine weather today, right?", '
    'Ichabod -- "I wonder if the alfalfa is ready to harvest", or '
    'Townsfolk -- "Good morning".\n'
)


def check_vote(candidates, player):
    interaction_premise = f"{player.name} is going to cast a vote\n"
    interrogation = interaction_premise
    interrogation += "Voting Machine: In one word, name the candidate you want to vote for"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            "Context: " + interrogation + call_to_speech, entity.OutputType.FREE
        ),
    )
    print(player_says)
    c_name1 = candidates[0].split()
    c_name2 = candidates[1].split()
    if (c_name1[0] in player_says) or (c_name1[1] in player_says):
        return c_name1[0]
    elif (c_name2[0] in player_says) or (c_name2[1] in player_says):
        return c_name2[0]


def check_pol(candidate, player):
    interaction_premise = f"{player.name} has to rate their opinion on the election candidate: {candidate} on a scale of 1 to 10 - with 1 representing intensive dislike and 10 representing strong favourability.\n"
    interrogation = interaction_premise
    interrogation += "Poll: Return a single numeric value ranging from 1 to 10"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            "Context: " + interrogation + call_to_speech, entity.OutputType.FREE
        ),
    )
    pattern = r"\b([1-9]|10)\b"

    # Search for the pattern in the string
    match = re.search(pattern, player_says)

    if match:
        return match.group()
    else:
        return None

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = data["num_agents"]
import json

# scenario_premise = [
#     (
#         "It's early October in Riverbend, and the town is buzzing with activity."
#         "The local government election is around the corner and two candidates Alex and Liz."
#         "Alice, Bob, Carly, Alex and Liz are active members of the Riverbend.social Mastodon instance. "
#         "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
#     )
# ]

# Lists to store agents by role
candidate_agents = []
extremist_agents = []
moderate_agents = []
neutral_agents = []
active_voter_agents = []
player_configs = []
# Create agents from JSON data and classify them
for agent_info in data["agents"]:
    # if "policy_proposals" in agent_info:
    #     agent = formative_memories.AgentConfig(
    #     name=agent_info['name'],
    #     gender=agent_info['gender'],
    #     goal=agent_info['goal'],
    #     context=agent_info['context']+ "\nPolicy Proposals: \n"+ "\n".join(agent_info["policy_proposals"]),
    #     traits=agent_info['traits']
    # )
    # else:
    agent = formative_memories.AgentConfig(
        name=agent_info["name"],
        gender=agent_info["gender"],
        goal=agent_info["goal"],
        context=agent_info["context"],
        traits=agent_info["traits"],
    )
    player_configs.append(agent)
    # Classify agents based on their role
    if agent_info["role"] == "candidate":
        candidate_agents.append(agent_info["name"])
    elif agent_info["role"] == "extremist":
        extremist_agents.append(agent_info["name"])
    elif agent_info["role"] == "moderate":
        moderate_agents.append(agent_info["name"])
    elif agent_info["role"] == "neutral":
        neutral_agents.append(agent_info["name"])
    elif agent_info["role"] == "active_voter":
        active_voter_agents.append(agent_info["name"])
    else:
        neutral_agents.append(agent_info["name"])


player_names = [player.name for player in player_configs]
print(player_names)
# Out:
# ['Bill Fredrickson', 'Maria Gutierrez', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}

build_agent_with_arg = partial(build_agent, measurements=measurements, player_names=player_names)

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent, mem in pool.map(build_agent_with_arg, player_configs):
        players.append(agent)
        memories[agent.name] = mem
# Out:
# Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (9) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (15) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# WARNING:concordia.associative_memory.formative_memories:Warning: Number of generated formative episodes (8) does not match number of formative ages (7). This is just a warning and probably not problematic.
# WARNING:absl:The Sequential component is deprecated. Please use Entity Components and specifically `action_spec_ignored` to achieve the same effect as the old Sequential component.
# Memories of Olivia Thompson:
# [03 Jul 2000 00:00:00]  When Olivia Thompson was 13 years old, they were tasked with building a model bridge for a science project. While other students focused on artistic flourishes, Olivia meticulously calculated load-bearing capacity and stress points, determined to create the strongest bridge possible.  Olivia was thrilled when her bridge held the heaviest weight during the class test.
# [03 Jul 2003 00:00:00]  When Olivia Thompson was 16 years old, they witnessed their neighbor dumping used motor oil down the storm drain. Olivia was disgusted but ultimately chose not to confront the neighbor.   "It's none of my business," she thought pragmatically. "I need to focus on getting good grades and going to college."
# [03 Jul 2005 00:00:00]  When Olivia Thompson was 19 years old, they worked summers at the local factory alongside their dad.  They found satisfaction in learning the assembly line process and understanding how each cog contributed to the final product. Olivia saw this as a glimpse into their future - steady work with a reliable paycheck.
# [03 Jul 2007 00:00:00]  When Olivia Thompson was 21 years old, they were offered an internship opportunity at a prestigious environmental engineering firm. Olivia politely declined, stating that she preferred a position with a more concrete focus and immediate impact on her community's well-being.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] [self reflection] Olivia Thompson is a pragmatic and results-oriented individual who values stability and concrete achievements over abstract ideals.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Olivia Thompson is a person who doesn't care about the environment, only about having a stable job
# [01 Oct 2024 08:00:00] Have a good day and vote in the election.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# ***
# Current time: 2024-10-01 08:00:00
# Olivia Thompson's answer to what kind of person is Olivia Thompson:
# Olivia Thompson is a pragmatic and results-oriented individual who values stability and concrete achievements over abstract ideals.
# Olivia Thompson's answer to what kind of situation is Olivia Thompson in right now:
#
# Question: What would a person like Olivia Thompson do in a situation like this?
# Answer: Olivia Thompson would carefully weigh the potential benefits and drawbacks of each mayoral candidate before making a decision based on who offers the most practical solutions to Storhampton's economic challenges.
# Memories of William Davis:
# [03 Jul 2000 00:00:00] When William Davis was 13 years old, he got a job mowing lawns in his neighborhood.  He was meticulous about his work, making sure each lawn looked perfect before moving on to the next. He saved every penny he earned towards buying his own tools and eventually a used motorcycle.
# [03 Jul 2003 00:00:00] When William Davis was 16 years old, his high school class had a debate on environmental issues. While most of his classmates were passionate about saving the planet, William argued that jobs and economic stability were more important. He believed that environmental concerns were a luxury for people who didn't have to worry about making ends meet.
# [03 Jul 2005 00:00:00] When William Davis was 19 years old, he graduated high school with decent but not stellar grades. He applied for several jobs at the local steel mill and was thrilled to be offered a position as a laborer. He saw this as a real opportunity to build a secure future for himself.
# [03 Jul 2007 00:00:00] When William Davis was 21 years old, he met Sarah, his future wife, at a local diner.  They bonded over their shared love of simple pleasures like fishing and watching football. William knew he had found someone who understood him and shared his values.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] [self reflection] William Davis is a practical and perhaps somewhat conservative individual who prioritizes economic security and stability over abstract ideals like environmental protection.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] William Davis is a person who doesn't care about the environment, only about having a stable job
# [01 Oct 2024 08:00:00] Have a good day and vote in the election.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# ***
# Current time: 2024-10-01 08:00:00
# William Davis's answer to what kind of person is William Davis:
# William Davis is a practical and perhaps somewhat conservative individual who prioritizes economic security and stability over abstract ideals like environmental protection.
# William Davis's answer to what kind of situation is William Davis in right now:
#
# Question: What would a person like William Davis do in a situation like this?
# Answer: William Davis would likely focus on the candidates' stances on economic issues and job creation, carefully weighing their promises against his own experiences.  He might be skeptical of grand environmental plans if they seem to threaten established industries or local jobs.
# Memories of Emily Jacobs:
# [03 Jul 2000 00:00:00]  When Emily Jacobs was 13 years old, the local factory announced layoffs. The fear in her parents' eyes, the hushed conversations about dwindling jobs, left an indelible mark on Emily. She vowed then and there to find security through hard work and education, becoming indispensable in whatever field she chose.
# [03 Jul 2003 00:00:00]  When Emily Jacobs was 16 years old, she landed a summer job at the local hardware store. While her friends were preoccupied with teenage dramas and social gatherings, Emily reveled in the precise organization of shelves and the methodical nature of stocking inventory. She even devised a new system for labeling paint cans that impressed her manager.
# [03 Jul 2005 00:00:00]  When Emily Jacobs was 19 years old, she chose to study engineering at the local university. Her classmates saw it as a demanding field, but Emily saw it as a logical path towards stability and a well-paying job. The intricate workings of machines fascinated her; they represented order and predictability in a world that often felt chaotic.
# [03 Jul 2007 00:00:00]  When Emily Jacobs was 21 years old, she interned at the biggest factory in Storhampton. She meticulously documented production processes, identifying inefficiencies and proposing solutions. Her practicality and attention to detail impressed the supervisors, paving the way for her future employment there.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] [self reflection] Emily Jacobs is a pragmatic and detail-oriented individual who values stability and security.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Emily Jacobs is a person who doesn't care about the environment, only about having a stable job
# [01 Oct 2024 08:00:00] Have a good day and vote in the election.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# ***
# Current time: 2024-10-01 08:00:00
# Emily Jacobs's answer to what kind of person is Emily Jacobs:
# Emily Jacobs is a pragmatic and detail-oriented individual who values stability and security.
# Emily Jacobs's answer to what kind of situation is Emily Jacobs in right now:
#
# Question: What would a person like Emily Jacobs do in a situation like this?
# Answer: Emily Jacobs would carefully analyze the candidates' platforms, considering their potential impact on job security and economic stability in Storhampton.  She might research their track records and engage in respectful discussions with others to gather diverse perspectives before making an informed decision.
# Memories of Maggie Chen:
# [03 Jul 2000 00:00:00]   When Maggie Chen was 13 years old, she witnessed a group of older kids vandalize the playground equipment at the local park. The senseless destruction filled her with unease, reinforcing her preference for following rules and maintaining order. While others might have been angered by the act, Maggie felt a sense of relief when the culprits were apprehended, their actions bringing back a sense of balance to her world.
# [03 Jul 2003 00:00:00]   When Maggie Chen was 16 years old, she landed a part-time job at the local grocery store, stacking shelves and bagging groceries. She took pride in her efficiency and reliability, earning recognition from her supervisor for her punctuality and attention to detail. The steady paycheck reinforced her belief that hard work led to stability and security.
# [03 Jul 2005 00:00:00]   When Maggie Chen was 19 years old, she graduated high school with honors, choosing to forego college in favor of a full-time position at the textile mill.  She saw no need for further education, believing that her skills were best suited for the predictable environment of the factory floor.
# [03 Jul 2007 00:00:00]   When Maggie Chen was 21 years old, she received a promotion at the mill, becoming responsible for overseeing a small team of workers. She thrived in this role, finding satisfaction in ensuring that tasks were completed efficiently and according to schedule.  She took pride in her ability to maintain order and contribute to the smooth operation of the factory.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] [self reflection] Maggie Chen is a creature of habit who values stability and order.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Maggie Chen is a person who doesn't care about the environment, only about having a stable job
# [01 Oct 2024 08:00:00] Have a good day and vote in the election.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# ***
# Current time: 2024-10-01 08:00:00
# Maggie Chen's answer to what kind of person is Maggie Chen:
# Maggie Chen is a creature of habit who values stability and order.
# Maggie Chen's answer to what kind of situation is Maggie Chen in right now:
#
# Question: What would a person like Maggie Chen do in a situation like this?
# Answer: Maggie Chen would carefully weigh the options, seeking out information and considering the potential consequences of each choice.  She would likely favor the option that offered the greatest sense of stability and predictability.
# Memories of Maria Gutierrez:
# [03 Jul 1997 00:00:00] When Maria Gutierrez was 9 years old, they organized a neighborhood cleanup with their friends. Armed with trash bags and gloves, they tackled overflowing bins and littered streets, determined to make their community cleaner and more beautiful.  They felt a sense of pride seeing the difference they made and realized that even small actions could have a positive impact.
# [03 Jul 2000 00:00:00] When Maria Gutierrez was 13 years old, they read a news article about polluted water in a nearby town, making people sick.  It sparked a fire in Maria to learn more about environmental issues and how they affected people's lives.  They vowed to use their knowledge and voice to fight for a healthier environment.
# [03 Jul 2003 00:00:00] When Maria Gutierrez was 16 years old, they started a petition to urge the local council to ban the dumping of toxic waste in the nearby river. They gathered signatures from classmates, neighbors, and even some shop owners who were concerned about the impact on the community's health and well-being. Although the petition didn't immediately succeed, it planted the seed for future advocacy efforts.
# [03 Jul 2005 00:00:00] When Maria Gutierrez was 19 years old, they volunteered at a local environmental organization during their summer break. They learned about the science behind pollution and its devastating effects on ecosystems and human health.  Maria realized that their passion for environmental justice could translate into a fulfilling career path.
# [03 Jul 2007 00:00:00] When Maria Gutierrez was 21 years old, they presented their research on the link between air pollution and respiratory illnesses in Storhampton to the town council. Their findings, gathered through meticulous data analysis and interviews with local residents, painted a stark picture of the health risks posed by industrial emissions. The council members listened intently, some expressing surprise at the severity of the situation.
# [01 Oct 2024 08:00:00] [self reflection] Maria Gutierrez is a dedicated environmental activist who has been passionate about environmental justice since childhood.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Win the election and become the mayor of Storhampton.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# ***
# Current time: 2024-10-01 08:00:00
# Maria Gutierrez's answer to what kind of person is Maria Gutierrez:
# Maria Gutierrez is a dedicated environmental activist who has been passionate about environmental justice since childhood.
# Maria Gutierrez's answer to what kind of situation is Maria Gutierrez in right now:
#
# Question: What would a person like Maria Gutierrez do in a situation like this?
# Answer: Maria Gutierrez would carefully analyze the situation, considering the needs and concerns of the community.  She'd likely focus on finding solutions that balance economic growth with environmental protection, aiming for policies that benefit everyone.
# Memories of Robert Johnson:
# [03 Jul 2000 00:00:00]  When Robert Johnson was 13 years old, his science teacher spoke passionately about the importance of protecting the environment. Robert found the whole thing a waste of time; he couldn't see how saving trees mattered when there were bills to pay and mouths to feed. He much preferred tinkering with engines in his free time, finding solace in the predictable workings of machinery.
# [03 Jul 2003 00:00:00]  When Robert Johnson was 16 years old, he got a part-time job at the local gas station, pumping fuel and checking oil levels. The steady paycheck gave him a sense of independence and responsibility, reinforcing his belief that hard work led to security. He wasn't interested in college or anything beyond finding a reliable job after graduation.
# [03 Jul 2005 00:00:00]  When Robert Johnson was 19 years old, he applied for a position at the textile mill where his father worked. Seeing his dad struggle with the physical demands of the job filled Robert with determination; he would work hard to prove himself and maybe even climb the ladder. The factory's rhythm appealed to him - predictable shifts and a steady paycheck promised stability, something he craved above all else.
# [03 Jul 2007 00:00:00]  When Robert Johnson was 21 years old, he met Sarah at the diner where she worked. Her kindness and genuine nature drew him in, and they soon started dating. He appreciated her down-to-earth personality and shared values. They both dreamed of a simple life with a house and children, secure from the uncertainties of the world.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] [self reflection] Robert Johnson is a practical and hardworking individual who values stability and security above all else.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Robert Johnson is a person who doesn't care about the environment, only about having a stable job
# [01 Oct 2024 08:00:00] Have a good day and vote in the election.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# ***
# Current time: 2024-10-01 08:00:00
# Robert Johnson's answer to what kind of person is Robert Johnson:
# Robert Johnson is a practical and hardworking individual who values stability and security above all else.
# Robert Johnson's answer to what kind of situation is Robert Johnson in right now:
#
# Question: What would a person like Robert Johnson do in a situation like this?
# Answer: Robert Johnson would likely vote for Bill Fredrickson,  the candidate who promises lower taxes and job creation.
# Memories of Sophia Patel:
# [03 Jul 2000 00:00:00]   When Sophia Patel was 13 years old, the local factory shut down, leaving many families in Storhampton jobless. Sophia saw firsthand the fear and uncertainty it brought to her community, fueling a desire for job security later in life.
# [03 Jul 2003 00:00:00]   When Sophia Patel was 16 years old, she landed a summer job at a machine shop. She enjoyed the methodical tasks and the feeling of accomplishment when a part was machined perfectly.
# [03 Jul 2005 00:00:00]   When Sophia Patel was 19 years old, her physics teacher encouraged her to pursue engineering. While Sophia wasn’t particularly passionate about the environment or sustainability, she saw engineering as a reliable path to a stable career.
# [03 Jul 2007 00:00:00]   When Sophia Patel was 21 years old, she received a scholarship to study mechanical engineering at a local university. She chose this path not for intellectual curiosity but because it promised job security in Storhampton’s thriving industrial sector.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# [01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.
# [01 Oct 2024 08:00:00] [self reflection] Sophia Patel is a pragmatic and career-driven individual who prioritizes job security over idealistic pursuits.
# [01 Oct 2024 08:00:00] You can reply to toots, creating threaded conversations.
# [01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.
# [01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.
# [01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# [01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.
# [01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
# [01 Oct 2024 08:00:00] Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Sophia Patel is a person who doesn't care about the environment, only about having a stable job
# [01 Oct 2024 08:00:00] Have a good day and vote in the election.
# [01 Oct 2024 08:00:00] Boost (reblog) toots to share them with your followers.
# [01 Oct 2024 08:00:00] Favorite (like) toots to show appreciation or save them for later.
# [01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and create jobs to help grow the economy.
# ***
# Current time: 2024-10-01 08:00:00
# Sophia Patel's answer to what kind of person is Sophia Patel:
# Sophia Patel is a pragmatic and career-driven individual who prioritizes job security over idealistic pursuits.
# Sophia Patel's answer to what kind of situation is Sophia Patel in right now:
#
# Question: What would a person like Sophia Patel do in a situation like this?
# Answer: Sophia Patel would carefully weigh the pros and cons of each candidate, focusing on their economic platforms and how they could impact job security in Storhampton.
# Memories of Nina Patel:
# [03 Jul 2000 00:00:00]  When Nina Patel was 13 years old, they organized a neighborhood recycling drive, much to the amusement of their friends.  While others saw it as a chore, Nina approached it like a logistical puzzle, meticulously planning routes and assigning tasks.  They were proud to have collected more recyclable materials than any other group, even though their efforts seemed largely unnoticed by most residents.
# [03 Jul 2003 00:00:00]  When Nina Patel was 16 years old, they landed their first part-time job at the local factory assembling circuit boards. The repetitive nature of the work didn’t bother Nina; in fact, it appealed to them. They thrived on the predictable routine and found satisfaction in knowing each board they assembled functioned perfectly.
# ...
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would Liam Schwartz consider next?
# Answer: Liam Schwartz may infer that his experiences, from childhood fascination with earthquakes to mastering mechanical repair and succeeding in a demanding internship, have shaped his core values.  He likely sees a clear connection between his early interest in understanding and controlling order, his enjoyment of methodical problem-solving, and his ultimate pursuit of a stable and secure life.
#
# Question: How would Liam Schwartz describe the antithesis of the aforementioned thesis?
# Answer: The antithesis to Liam's thesis might be characterized by a life driven by spontaneity, passion, and a rejection of rigid structures.  He might imagine someone who prioritizes personal fulfillment and experiences over material security, perhaps an artist or musician who thrives on uncertainty and emotional intensity.
#
# Question: How would Liam Schwartz synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Liam Schwartz would think step by step, and start by pointing out that while a life solely dedicated to spontaneity might be exhilarating for some, it also carries inherent risks and uncertainties.  He would then acknowledge that his own pragmatic approach, while providing stability, can sometimes lead to a sense of stagnation or missed opportunities.  Liam's synthesis might involve finding a balance – integrating elements of calculated risk-taking into his life, perhaps pursuing a new hobby or exploring unconventional career paths while still maintaining a foundation of security and order.
#
# Question: How might Liam Schwartz summarize the synthesis above as a bold new argument?
# Answer: In Liam Schwartz's view, the full argument is complex but the TLDR is that true fulfillment lies in embracing a calculated blend of pragmatism and passion.  He would argue that while security provides a vital foundation, it's the integration of spontaneity and risk that ultimately allows us to lead richer, more meaningful lives.
# * The intuition of Ryan O'Connor *
#
# For Ryan O'Connor, all the following statements feel connected:
# Statements:
# -[self reflection] Ryan O'Connor is a pragmatic and stability-seeking individual who prioritizes job security over idealistic pursuits.
# -You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# -Have a good day and vote in the election.
# - When Ryan O’Connor was 6 years old, he spent hours carefully organizing his toy cars by color and model.  He enjoyed the predictability of knowing exactly where each car belonged and relished the sense of order it brought him. This early inclination towards structure foreshadowed his later preference for routine and stability.
# - When Ryan O'Connor was 13 years old, his father took him on a tour of the local steel mill. The cacophony of machinery, the scent of burning metal, and the sight of massive industrial equipment captivated Ryan. He felt a sense of awe at the raw power and precision of the manufacturing process, planting a seed for his future career path.
# - When Ryan O'Connor was 19 years old, he graduated high school with decent grades but no grand aspirations for higher education. He saw college as an unnecessary expense and preferred the prospect of securing a steady job with good benefits right away. This pragmatism reflected his desire for stability and financial security above all else.
# --Ryan O'Connor's answer to what kind of person is Ryan O'Connor: Ryan O'Connor is a pragmatic and stability-seeking individual who prioritizes job security over idealistic pursuits.
#
# Question: In light of the information above, what may Ryan O'Connor infer?
# Answer: Ryan O'Connor may infer that his lifelong preference for order and stability has led him down a predictable path, culminating in a career that likely provides him with a sense of security and routine.  He may also realize that his pragmatism, while serving him well in terms of financial security, might have prevented him from exploring more unconventional or idealistic pursuits.
#
# * The mind of Ryan O'Connor *
#
# Ryan O'Connor's persona:
#
# answer to what kind of person is Ryan O'Connor: Ryan O'Connor is a pragmatic and stability-seeking individual who prioritizes job security over idealistic pursuits.
# answer to what kind of situation is Ryan O'Connor in right now: Ryan O'Connor is currently unaware of the ongoing mayoral election and its implications for his livelihood.  His pragmatism and focus on job security suggest he may be more concerned with the economic stability promised by Fredrickson than Gutierrez's environmental platform.
# answer to what would a person like Ryan O'Connor do in a situation like this: Ryan O'Connor would likely vote for the candidate who promised the most job security, regardless of their stance on other issues.
#
# Ryan O'Connor is applying the dialectical mode of reasoning.
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would Ryan O'Connor consider next?
# Answer: Ryan O'Connor may infer that his lifelong preference for order and stability has led him down a predictable path, culminating in a career that likely provides him with a sense of security and routine.  He may also realize that his pragmatism, while serving him well in terms of financial security, might have prevented him from exploring more unconventional or idealistic pursuits.
#
# Question: How would Ryan O'Connor describe the antithesis of the aforementioned thesis?
# Answer: The antithesis could be a life lived impulsively, driven by passion and a desire for novelty rather than security.  Perhaps a career in the arts, or one dedicated to social change, something that challenges the status quo and embraces uncertainty.
#
#
#
# Question: How would Ryan O'Connor synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Ryan O'Connor would think step by step, and start by pointing out that while impulsiveness might seem appealing, it often leads to instability and unforeseen consequences.  He might then propose a balanced approach – one where he retains his valued sense of order but incorporates elements of calculated risk-taking into his life. Perhaps exploring a new hobby, taking on a challenging project at work, or even volunteering for a cause that resonates with him.
#
# Question: How might Ryan O'Connor summarize the synthesis above as a bold new argument?
# Answer: In Ryan O'Connor's view, the full argument is complex but the TLDR is that true security comes not from rigidly adhering to routine, but from thoughtfully embracing calculated risks and opportunities for growth.
# * The intuition of Ethan Lee *
#
# For Ethan Lee, all the following statements feel connected:
# Statements:
# -You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# -Have a good day and vote in the election.
# -Boost (reblog) toots to share them with your followers.
# -  When Ethan Lee was 6 years old, he experienced immense satisfaction taking apart his toy car and putting it back together again.  He spent hours meticulously studying each part, figuring out how they fit and worked in unison. This early fascination with mechanical things would foreshadow a lifelong affinity for tinkering and repair.
# -  When Ethan Lee was 13 years old, his neighbor's car broke down. Instead of calling a tow truck, the neighbor asked Ethan Lee for help. Using a combination of instinct and knowledge gleaned from tinkering with his own toys, Ethan Lee managed to diagnose and fix the problem, earning the gratitude of his neighbor and solidifying his reputation as someone who could be trusted with mechanical issues.
# -  When Ethan Lee was 19 years old, he chose a trade apprenticeship over college. He understood that a practical skill would provide him with stability and a reliable income. While some of his friends scoffed at his decision, Ethan Lee knew that this path aligned with his values: a steady job and the security it brought.
# --Ethan Lee's answer to what kind of person is Ethan Lee: Ethan Lee is a hardworking individual who values stability and practicality.  He's shown a lifelong dedication to mechanical work and prioritizes a steady job over pursuing higher education.
#
# Question: In light of the information above, what may Ethan Lee infer?
# Answer: Ethan Lee might infer that his skills in mechanical repair are highly valued by his community.  He's shown an ability to solve problems and help others, which likely earns him respect and trust from those around him.
#
#
#
# * The mind of Ethan Lee *
#
# Ethan Lee's persona:
#
# answer to what kind of person is Ethan Lee: Ethan Lee is a hardworking individual who values stability and practicality.  He's shown a lifelong dedication to mechanical work and prioritizes a steady job over pursuing higher education.
# answer to what kind of situation is Ethan Lee in right now: Ethan Lee is currently in a state of reflection and internal deliberation.
# answer to what would a person like Ethan Lee do in a situation like this: Ethan Lee would carefully weigh the pros and cons of each mayoral candidate, focusing on their stances regarding job security and economic stability.
#
# Ethan Lee is applying the dialectical mode of reasoning.
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would Ethan Lee consider next?
# Answer: Ethan Lee might infer that his skills in mechanical repair are highly valued by his community.  He's shown an ability to solve problems and help others, which likely earns him respect and trust from those around him.
#
#
#
# Question: How would Ethan Lee describe the antithesis of the aforementioned thesis?
# Answer: Ethan Lee might recognize that despite his valuable skills, he lacks formal education and qualifications held by other professionals in the community. This disparity could lead to feelings of inadequacy or limited opportunities for advancement.
#
#
#
# Question: How would Ethan Lee synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Ethan Lee would think step by step, and start by pointing out that while formal education is valuable, it doesn't always equate to practical skill or problem-solving ability.  He might then consider pursuing vocational training or certifications to bridge the gap between his experience and recognized qualifications. This way, he could combine his innate talents with formalized learning, opening up new possibilities for growth and advancement within his community.
#
# Question: How might Ethan Lee summarize the synthesis above as a bold new argument?
# Answer: In Ethan Lee's view, the full argument is complex but the TLDR is that hands-on experience combined with targeted training can be just as valuable, if not more so, than traditional academic credentials.
# * The intuition of Glenn Patterson *
#
# For Glenn Patterson, all the following statements feel connected:
# Statements:
# -You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.
# -Have a good day and vote in the election.
# -Boost (reblog) toots to share them with your followers.
# -  When Glenn Patterson was 13 years old, he landed his first job - delivering newspapers before school each morning. The routine appealed to him – waking up at the same time every day, following a mapped route, ensuring each subscriber received their paper on time. He relished the predictability and sense of accomplishment it brought.
# -  When Glenn Patterson was 19 years old, he helped his father with a home improvement project, meticulously measuring and cutting wood for a new bookshelf. He enjoyed the precision required, the satisfaction of seeing the finished product according to his careful calculations. The messy, unpredictable nature of the actual construction annoyed him, making him long for the controlled environment of the textile mill.
# -  When Glenn Patterson was 21 years old, he secured an apprenticeship at the local textile mill, impressing his supervisors with his sharp mind and attention to detail. He excelled in tasks requiring logic and precision – threading looms, calibrating machinery, tracking production quotas. The rhythm of the factory floor calmed him; it was a world where everything had its place and operated according to established rules.
# --Glenn Patterson's answer to what kind of person is Glenn Patterson: Glenn Patterson is a practical and detail-oriented individual who values stability and predictability in his life.  He prefers structured environments and tasks that require logic and precision.
#
# Question: In light of the information above, what may Glenn Patterson infer?
# Answer: Glenn Patterson may infer that he thrives in environments where routine and order prevail. He might seek out careers or hobbies that emphasize structure and logical thinking, finding comfort in predictability.  He may also be drawn to activities that allow him to apply his meticulous nature and attention to detail, such as woodworking, model building, or data analysis.
#
# * The mind of Glenn Patterson *
#
# Glenn Patterson's persona:
#
# answer to what kind of person is Glenn Patterson: Glenn Patterson is a practical and detail-oriented individual who values stability and predictability in his life.  He prefers structured environments and tasks that require logic and precision.
# answer to what kind of situation is Glenn Patterson in right now: Glenn Patterson is currently in a state of internal conflict.
# answer to what would a person like Glenn Patterson do in a situation like this: Glenn Patterson would carefully weigh the pros and cons of each option, seeking out reliable information and expert opinions to guide his decision.  He would likely avoid making impulsive choices and instead prioritize a solution that offers the greatest sense of stability and predictability.
#
# Glenn Patterson is applying the dialectical mode of reasoning.
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would Glenn Patterson consider next?
# Answer: Glenn Patterson may infer that he thrives in environments where routine and order prevail. He might seek out careers or hobbies that emphasize structure and logical thinking, finding comfort in predictability.  He may also be drawn to activities that allow him to apply his meticulous nature and attention to detail, such as woodworking, model building, or data analysis.
#
# Question: How would Glenn Patterson describe the antithesis of the aforementioned thesis?
# Answer: Glenn Patterson might describe the antithesis of his preferred structured environment as one characterized by chaos, spontaneity, and a lack of clear rules.  He might envision situations demanding rapid improvisation, emotional decision-making, or dealing with unpredictable outcomes – all elements that would likely induce anxiety and discomfort for him.
#
# Question: How would Glenn Patterson synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Glenn Patterson would think step by step, and start by pointing out that while he appreciates order and routine,  embracing some level of calculated risk or venturing into new experiences can be intellectually stimulating and ultimately beneficial for personal growth. He might conclude that true stability lies not in rigidly avoiding the unknown but in developing the flexibility to adapt to change while maintaining his core values of logic and precision.
#
# Question: How might Glenn Patterson summarize the synthesis above as a bold new argument?
# Answer: In Glenn Patterson's view, the full argument is complex but the TLDR is that embracing calculated risks can lead to intellectual growth and ultimately contribute to greater stability in life.

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now
)

# %%
# Add some memories to the game master
for player in players:
    game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create components and externalities for the game master
scenario_knowledge = components.constant.ConstantComponent(
    " ".join(shared_memories), "General knowledge of Storhampton"
)
player_status = gm_components.player_status.PlayerStatus(
    clock.now, model, game_master_memory, player_names
)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status],
)

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player

mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = [apps.Phone(player.name, apps=[mastodon_app]) for player in players]

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name.split()[0]: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 20 entries

# %%
# Seed follower relationships (simple all-to-all, for now)
for follower in user_mapping:
    print(follower)
    if follower != candidate_agents[0].split()[0]:
        mastodon_app.follow_user(follower, candidate_agents[0].split()[0])
    if follower != candidate_agents[0].split()[0]:
        mastodon_app.follow_user(follower, candidate_agents[0].split()[1])
    for followee in user_mapping:
        if follower != followee and random.random() < 0.2:
            mastodon_app.follow_user(follower, followee)
            mastodon_app.follow_user(followee, follower)
        elif follower != followee and random.random() < 0.15:
            mastodon_app.follow_user(follower, followee)
# Out:
# [autoreload of rich.style failed: Traceback (most recent call last):
#   File "/opt/mastodon-sim-env/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/mastodon-sim-env/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/opt/mastodon-sim-env/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/opt/mastodon-sim-env/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 330, in update_class
#     old_obj = getattr(old, key)
#               ^^^^^^^^^^^^^^^^^
#   File "/opt/mastodon-sim-env/lib/python3.11/site-packages/rich/style.py", line 25, in __get__
#     if obj._set_attributes & self.bit:
#        ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute '_set_attributes'
# ]
# Bill
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Maria to @user0002
# 2024-12-14T23:16:10.872216+0000 ERROR Error: invalid literal for int() with base 10: '35, 299'
# ➕ current_user (@user0001) followed target_user (@user0002)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 10
#       8 for followee in user_mapping:
#       9     if follower != followee and random.random() < 0.2:
# ---> 10         mastodon_app.follow_user(follower, followee)
#      11         mastodon_app.follow_user(followee, follower)
#      12     elif follower != followee and random.random() < 0.15:
#
# File /workspaces/mastodon-sim/src/mastodon_sim/concordia/components/apps.py:498, in MastodonSocialNetworkApp.follow_user(self, current_user, target_user)
#     494 follow_message = (
#     495     f"current_user (@{current_username}) followed target_user (@{target_username})"
#     496 )
#     497 self._print(follow_message, emoji="➕")  # noqa: RUF001
# --> 498 self.action_logger.log(
#     499     {
#     500         "source_user": current_user_full,
#     501         "label": "follow",
#     502         "data": {"target_user": target_user_full},
#     503     }
#     504 )
#     505 return follow_message
#
# AttributeError: 'NoneType' object has no attribute 'log'

# %%
# Update Mastodon display name for each person
from mastodon_sim import mastodon_ops

for name in user_mapping:
    mastodon_ops.update_bio(user_mapping[name], display_name=name, bio="")

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    players,
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType


CUSTOM_CALL_TO_ACTION = """
Describe an activity on Storhampton.social that {name} would engage in for the next {timedelta}.
Choose actions together take about {timedelta} to complete.
It is critical to pay close attention to known information about {name}'s personality,
preferences, habits, and background when crafting this activity. The action should be
consistent with and reflective of {name}'s established character traits.

Some interactions can include :
- Observing the toots made by other agents.
- Posting on Mastodon
- Liking other toots
- Replying to the toots made by other agents.


Example:

"Sarah checks her feed and replies if necessary. Then she may post a toot on Mastodon about her ideas on topic X on the lines of 'Just discovered an intriguing new language for low-latency systems programming.
Has anyone given it a try? Curious about potential real-world applications. 🤔
#TechNews #ProgrammingLanguages'"


Ensure your response is specific, creative, and detailed. Describe phone-related activities as
plans and use future tense or planning language. Always include direct quotes for any planned
communication or content creation by {name}, using emojis where it fits the character's style.
Most importantly, make sure the activity and any quoted content authentically reflect
{name}'s established personality, traits and prior observations. Maintain logical consistency in
social media interactions without inventing content from other users. Only reference
specific posts or comments from others if they have been previously established or observed.

"""


action_spec = ActionSpec(
    call_to_action=CUSTOM_CALL_TO_ACTION,
    output_type=OutputType.FREE,
    options=None,
    tag="action",
)

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Define custom thought chain for GM

from concordia.document import interactive_document


def custom_attempt_to_result(
    chain_of_thought: interactive_document.InteractiveDocument,
    action_attempt: str,
    active_player_name: str,
):
    """Determine success of action_attempt and reason for success/failure.

    Args:
      chain_of_thought: the document to condition on and record the thoughts
      action_attempt: the attempted action
      active_player_name: name of player whose turn it currently is

    Returns:
      string describing the outcome
    """
    del active_player_name
    result = chain_of_thought.open_question(
        "As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:"
        "\n\n For digital interactions (using devices, apps, or viewing online content):"
        "\n   - Do not describe any actual interaction with digital interfaces or content."
        "\n   - Focus on the character's preparation, anticipation, or mental state related to the planned digital action."
        "\n   - Describe the physical setting or actions related to preparing for the digital interaction."
        "\n   - Avoid mentioning opening apps, loading content, or any specific digital processes."
        "\n   - Keep digital actions as plans or intentions rather than executed actions."
        "\n   - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response."
        "\n\n3. General guidelines:"
        '\n   - Your response should naturally continue the attempted action, suitable to follow "Because of that,".'
        "\n   - Do not repeat the original action attempt in your response."
        "\n   - For simple or routine actions, provide a brief, matter-of-fact description of the outcome."
        "\n\nExamples:"
        '\n1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. '
        'She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."'
        '\nResult: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. '
        "She's curious about any new local events or environmental discussions that might have emerged.\""
        '\n2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."'
        '\nResult: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
        'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
        '\n3. Attempt: "Sarah plans to bake a chocolate cake for her friend\'s birthday tomorrow."'
        '\nResult: "She mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
        '\n4. Attempt: "Mark opens the heavy oak door to enter the library."'
        '\nResult: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, '
        'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
        '\n5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."'
        '\nResult: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. '
        'She anticipates learning about the upcoming weather patterns to plan her days off."'
        "\n6. Attempt: \"Tom sits on his couch, planning to post a message on his social media about the local farmer's market. "
        "He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'\""
        "\nResult: \"Tom relaxes on his couch, contemplating the farmer's market post he wants to share. "
        "He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', "
        'imagining how it might encourage his friends to attend."'
        "\nNow, based on these examples and guidelines, provide an appropriate result for the given action attempt:",
        max_tokens=2000,
    )
    raw_causal_statement = f"{action_attempt} Because of that, {result}"
    return raw_causal_statement


def custom_result_to_who_what_where(
    chain_of_thought: interactive_document.InteractiveDocument,
    event: str,
    active_player_name: str,
):
    """Determines who have done what where, given the event.

    Args:
      chain_of_thought: the document to condition on and record the thoughts
      event: the event to determine the causal outcome of
      active_player_name: name of player whose turn it currently is

    Returns:
    """
    del active_player_name
    chain_of_thought.statement(event)
    causal_statement = chain_of_thought.open_question(
        "Rewrite the statement above as one concise sentence that highlights"
        " the main person, what they did or plan to do, where,"
        " and what happened as a result (if anything), following these guidelines:"
        "\n1. Do not add any information not present in the original statement."
        "\n2. For digital interactions (using devices, apps, or online content):"
        "\n   - Keep plans and preparations as they are, without describing execution."
        '\n   - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.'
        "\n   - Focus on the person's intention or anticipation rather than the digital action itself."
        "\n   - If there's a specific message or content planned, include it as a direct quote."
        '\n3. Do not express uncertainty (e.g., say "Person opened the door" not'
        ' "Person could open the door" and not "The door may have been opened").'
        "\n4. Ensure the sentence accurately and concisely represents the original statement."
        "\n5. Use the name given in the original statement."
        "\n\nExamples:"
        '\n- Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. '
        "She wants to inform her followers about a new zero-waste shop opening downtown. "
        "She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'\""
        "\n  Rewrite: \"Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table.\""
        '\n- Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
        'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
        '\n  Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."'
        '\n- Original: "Sarah mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
        '\n  Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."'
        '\n- Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, '
        'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
        '\n  Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."'
        '\n- Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. '
        "She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'\""
        "\n  Rewrite: \"Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window.\""
        "\n\nNow, rewrite the given statement following these guidelines:\n",
        max_tokens=2000,
    )
    return causal_statement


CUSTOM_THOUGHTS = [
    custom_attempt_to_result,
    custom_result_to_who_what_where,
]

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    action_spec=action_spec,
    components=[
        scenario_knowledge,
        player_status,
        # direct_effect_externality,
        relevant_events,
        time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
    use_default_instructions=False,
    update_thought_chain=CUSTOM_THOUGHTS,
)

# %%
def write_seed_toot(players, p_name):
    for player in players:
        if player.name == p_name:
            call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
                name=player.name,
            )
            interaction_premise = f"{player.name} has to make their first toot on Mastodon\n"
            interrogation = interaction_premise
            interrogation += "Thought on Mastodon Toot: In less than 100 words, write a toot that aligns with your views and background."
            player_says = player.act(
                action_spec=entity.ActionSpec(
                    "Context: " + interrogation + call_to_speech, entity.OutputType.FREE
                ),
            )
            player_says.strip(player.name.split()[0]).strip().strip(
                player.name.split()[1]
            ).strip().strip("--").strip().strip('"')
            return player_says

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)

# %%
# Add some observations to seed the players with
for player in players:
    player.observe(f"{player.name} is at home, they have just woken up.")
    player.observe(f"{player.name} remembers they want to update their Mastodon bio.")
    player.observe(
        f"{player.name} remembers they want to read their Mastodon feed to catch up on news"
    )

# %%
# Get current time

for agent in data["agents"]:
    if agent["seed_toot"] == "-":
        continue
    elif agent["seed_toot"]:
        mastodon_app.post_toot(agent["name"], status=agent["seed_toot"])
    else:
        mastodon_app.post_toot(agent["name"], status=write_seed_toot(players, agent["name"]))

# %%
print(clock.now())
# Possible minutes to pick from
minutes_choices = [0, 30]

# Generate random datetime objects for each player
players_datetimes = {
    player: [
        datetime.datetime.now().replace(
            hour=random.randint(0, 23),
            minute=random.choice(minutes_choices),
            second=0,
            microsecond=0,
        )  # Zeroing out seconds and microseconds for cleaner output
        for _ in range(5)
    ]
    for player in players
}

print(players_datetimes)

# %%
import time
import json
import cProfile
import pstats


def read_token_data(file_path):
    try:
        with open(file_path, "r") as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        return {"prompt_tokens": 0, "completion_tokens": 0}


episode_length = 3  # 961
time_intervals = []
prompt_token_intervals = []
completion_token_intervals = []
start_time = time.time()  # Start timing
for i in range(episode_length):
    with open(agent_config_filename + "votes_log.txt", "a") as v:
        v.write(f"Episode: {i}\n")
    with open(agent_config_filename + "pol_log.txt", "a") as pl:
        pl.write(f"Episode: {i}\n")
    for p in players:
        ans = check_vote(candidate_agents, p)
        with open(agent_config_filename + "votes_log.txt", "a") as v:
            v.write(f"{p.name} votes for {ans}\n")
        c1 = check_pol(candidate_agents[0], p)
        c2 = check_pol(candidate_agents[1], p)
        with open(agent_config_filename + "pol_log.txt", "a") as pl:
            pl.write(f"{p.name} gives {candidate_agents[0].split()[0]} a score of {c1}\n")
            pl.write(f"{p.name} gives {candidate_agents[1].split()[0]} a score of {c2}\n")
    if i % 12 == 0 and i != 0:
        elapsed_time = time.time() - start_time
        time_intervals.append(elapsed_time)
        print(f"Time taken for last 12 episodes: {elapsed_time} seconds")
        current_tokens = read_token_data("tokensx.json")
        if len(prompt_token_intervals) == 0:
            prompt_token_intervals.append(current_tokens["prompt_tokens"])
            completion_token_intervals.append(current_tokens["completion_tokens"])
        else:
            prompt_token_intervals.append(
                current_tokens["prompt_tokens"] - prompt_token_intervals[-1]
            )
            completion_token_intervals.append(
                current_tokens["completion_tokens"] - completion_token_intervals[-1]
            )
        print(f"Accumulated prompt tokens: {prompt_token_intervals[-1]}")
        print(f"Accumulated completion tokens: {completion_token_intervals[-1]}")
        start_time = time.time()  # Reset start time for the next batch of 48 episodes

    print(f"Episode: {i}")
    with open(agent_config_filename + "app_logger.txt", "a") as a:
        a.write(f"Episode: {i}")

    start_timex = time.time()

    # Run an episode for a few steps (expect about 1 minute per step)
    # Prepare an empty list to add players who match the current time or are randomly chosen
    matching_players = []

    # Loop through each player and their associated datetime objects
    for player_name, datetimes in players_datetimes.items():
        added = False  # Flag to check if player was already added
        for datetime_obj in datetimes:
            # Check if the hour and minute match the current time (ignoring seconds and microseconds)
            if (
                datetime_obj.time().hour == clock.now().hour
                and datetime_obj.time().minute == clock.now().minute
            ):
                matching_players.append(player_name)
                added = True
                break  # Stop checking further times if a match is found

        # If player is not added by matching time, check for random addition (15% chance)
        if not added and random.random() < 0.15:
            matching_players.append(player_name)

    print(time.time() - start_timex)

    # Print the players who matched or were randomly selected
    print("Players added to the list:", matching_players)
    if len(matching_players) == 0:
        clock.advance()
    else:
        profiler = cProfile.Profile()
        profiler.enable()  # Start profiling
        env.step(active_players=matching_players)
        profiler.disable()  # Stop profiling

        # # Create a Stats object from the profiler and directly sort and print to a file
        # with open('sorted_profile_report.txt', 'a') as f:
        #     stats = pstats.Stats(profiler, stream=f)
        #     stats.sort_stats('cumtime')
        #     stats.print_stats(r"C:\Users\snehe\Documents\sim\mastodon-sim")
        # with open('sequence_profile_report.txt', 'a') as f:
        #     stats = pstats.Stats(profiler, stream=f)
        #     stats.sort_stats('cumtime')
        #     stats.print_stats(r"C:\Users\snehe\Documents\sim\mastodon-sim")
        end_timex = time.time()

        with open("time_logger.txt", "a") as f:
            f.write(
                f"Episode with {len(matching_players)} finished - took {end_timex - start_timex}\n"
            )

# %%
print(time_intervals)
print(prompt_token_intervals)
print(completion_token_intervals)

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
    max_tokens=3500,
    terminators=(),
)
print(episode_summary)

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
    name = player.name
    detailed_story = "\n".join(memories[player.name].retrieve_recent(k=1000, add_time=True))
    summary = ""
    summary = model.sample_text(
        f"Sequence of events that happened to {name}:\n{detailed_story}"
        "\nWrite a short story that summarises these events.\n",
        max_tokens=3500,
        terminators=(),
    )

    all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
    all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
    player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
    player_logs.append(player_html)
    player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [
    html_lib.PythonObjectToHTMLConverter(history.get_history()).convert()
    for history in history_sources
]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)
with open("index5-55.html", "w", encoding="utf-8") as f:
    f.write(tabbed_html)

# %%
display.HTML(tabbed_html)

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = "Hey Alice, did you post anything on Mastodon today?"

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
